# %% [markdown]
# # MNIST-Neural Network-Two Hidden Layers with Modules (and Backward Propagation)

# %%
# coding: utf-8
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import math

sys.path.append(os.pardir)
from common.mnist import *
from common.networks import *

# %% [markdown]
# ## Multilayer Neural Network Model

# %%
data = mnist_data("/Users/yhhan/git/aiclass/0.Professor/data/MNIST_data/.")
(img_train, label_train), (img_validation, label_validation), (img_test, label_test) = data.load_mnist(flatten=True, normalize=True, one_hot_label=True)

input_size=784
hidden_layer1_size=128
hidden_layer2_size=128
output_size=10

network = MultiLayerNet(input_size, 
                        [hidden_layer1_size, hidden_layer2_size], 
                        output_size, 
                        activation='ReLU', 
                        initializer='N2')

# %% [markdown]
# ## Learning and Validation

# %%
import math

num_epochs = 50
train_size = img_train.shape[0]
batch_size = 1000
learning_rate = 0.1

train_error_list = []
validation_error_list = []

test_accuracy_list = []
epoch_list = []

num_batch = math.ceil(train_size / batch_size)

for i in range(num_epochs):
#     batch_mask = np.random.choice(train_size, batch_size)
#     x_batch = img_train[batch_mask]
#     t_batch = label_train[batch_mask]
#     network.learning(learning_rate, x_batch, t_batch)
    for j in range(num_batch):
        x_batch = img_train[j * batch_size : j * batch_size + batch_size]
        t_batch = label_train[j * batch_size : j * batch_size + batch_size]
        network.learning(learning_rate, x_batch, t_batch, optimizer = "SGD")

    epoch_list.append(i)
    
    train_loss = network.loss(x_batch, t_batch)
    train_error_list.append(train_loss)
    
    validation_loss = network.loss(img_validation, label_validation)
    validation_error_list.append(validation_loss)    
    
    test_accuracy = network.accuracy(img_test, label_test)
    test_accuracy_list.append(test_accuracy)       
    
    print("Epoch: {0:5d}, Train Error: {1:7.5f}, Validation Error: {2:7.5f} - Test Accuracy: {3:7.5f}".format(
        i,
        train_loss,
        validation_loss,
        test_accuracy
    ))
# Out:
# Epoch:     0, Train Error: 2.30159, Validation Error: 2.30135 - Test Accuracy: 0.11350
# Epoch:     1, Train Error: 2.30027, Validation Error: 2.29988 - Test Accuracy: 0.11350
# Epoch:     2, Train Error: 2.29668, Validation Error: 2.29619 - Test Accuracy: 0.11350
# Epoch:     3, Train Error: 2.27651, Validation Error: 2.27604 - Test Accuracy: 0.20760
# Epoch:     4, Train Error: 2.06732, Validation Error: 2.06964 - Test Accuracy: 0.30380
# Epoch:     5, Train Error: 1.42610, Validation Error: 1.41904 - Test Accuracy: 0.57420
# Epoch:     6, Train Error: 0.84812, Validation Error: 0.80553 - Test Accuracy: 0.72320
# Epoch:     7, Train Error: 0.66876, Validation Error: 0.60909 - Test Accuracy: 0.78780
# Epoch:     8, Train Error: 0.58639, Validation Error: 0.52149 - Test Accuracy: 0.81980
# Epoch:     9, Train Error: 0.52768, Validation Error: 0.45989 - Test Accuracy: 0.84330
# Epoch:    10, Train Error: 0.48782, Validation Error: 0.41548 - Test Accuracy: 0.85910
# Epoch:    11, Train Error: 0.46075, Validation Error: 0.38555 - Test Accuracy: 0.86820
# Epoch:    12, Train Error: 0.43814, Validation Error: 0.36243 - Test Accuracy: 0.87440
# Epoch:    13, Train Error: 0.41761, Validation Error: 0.34272 - Test Accuracy: 0.88100
# Epoch:    14, Train Error: 0.39768, Validation Error: 0.32490 - Test Accuracy: 0.88730
# Epoch:    15, Train Error: 0.37903, Validation Error: 0.30853 - Test Accuracy: 0.89240
# Epoch:    16, Train Error: 0.36138, Validation Error: 0.29372 - Test Accuracy: 0.89730
# Epoch:    17, Train Error: 0.34424, Validation Error: 0.28025 - Test Accuracy: 0.90030
# Epoch:    18, Train Error: 0.32798, Validation Error: 0.26729 - Test Accuracy: 0.90470
# Epoch:    19, Train Error: 0.31258, Validation Error: 0.25550 - Test Accuracy: 0.90880
# Epoch:    20, Train Error: 0.29783, Validation Error: 0.24459 - Test Accuracy: 0.91350
# Epoch:    21, Train Error: 0.28369, Validation Error: 0.23426 - Test Accuracy: 0.91750
# Epoch:    22, Train Error: 0.27049, Validation Error: 0.22478 - Test Accuracy: 0.92010
# Epoch:    23, Train Error: 0.25809, Validation Error: 0.21604 - Test Accuracy: 0.92350
# Epoch:    24, Train Error: 0.24637, Validation Error: 0.20798 - Test Accuracy: 0.92630
# Epoch:    25, Train Error: 0.23523, Validation Error: 0.20031 - Test Accuracy: 0.92940
# Epoch:    26, Train Error: 0.22487, Validation Error: 0.19312 - Test Accuracy: 0.93280
# Epoch:    27, Train Error: 0.21510, Validation Error: 0.18627 - Test Accuracy: 0.93480
# Epoch:    28, Train Error: 0.20574, Validation Error: 0.17998 - Test Accuracy: 0.93660
# Epoch:    29, Train Error: 0.19681, Validation Error: 0.17404 - Test Accuracy: 0.93800
# Epoch:    30, Train Error: 0.18847, Validation Error: 0.16849 - Test Accuracy: 0.94030
# Epoch:    31, Train Error: 0.18059, Validation Error: 0.16340 - Test Accuracy: 0.94190
# Epoch:    32, Train Error: 0.17313, Validation Error: 0.15866 - Test Accuracy: 0.94340
# Epoch:    33, Train Error: 0.16630, Validation Error: 0.15419 - Test Accuracy: 0.94500
# Epoch:    34, Train Error: 0.15984, Validation Error: 0.15016 - Test Accuracy: 0.94620
# Epoch:    35, Train Error: 0.15382, Validation Error: 0.14648 - Test Accuracy: 0.94800
# Epoch:    36, Train Error: 0.14825, Validation Error: 0.14308 - Test Accuracy: 0.94970
# Epoch:    37, Train Error: 0.14307, Validation Error: 0.13993 - Test Accuracy: 0.95030
# Epoch:    38, Train Error: 0.13826, Validation Error: 0.13698 - Test Accuracy: 0.95080
# Epoch:    39, Train Error: 0.13356, Validation Error: 0.13423 - Test Accuracy: 0.95130
# Epoch:    40, Train Error: 0.12921, Validation Error: 0.13168 - Test Accuracy: 0.95240
# Epoch:    41, Train Error: 0.12520, Validation Error: 0.12925 - Test Accuracy: 0.95350
# Epoch:    42, Train Error: 0.12136, Validation Error: 0.12698 - Test Accuracy: 0.95470
# Epoch:    43, Train Error: 0.11783, Validation Error: 0.12484 - Test Accuracy: 0.95560
# Epoch:    44, Train Error: 0.11442, Validation Error: 0.12290 - Test Accuracy: 0.95630
# Epoch:    45, Train Error: 0.11110, Validation Error: 0.12098 - Test Accuracy: 0.95760
# Epoch:    46, Train Error: 0.10805, Validation Error: 0.11910 - Test Accuracy: 0.95880
# Epoch:    47, Train Error: 0.10505, Validation Error: 0.11732 - Test Accuracy: 0.95930
# Epoch:    48, Train Error: 0.10229, Validation Error: 0.11581 - Test Accuracy: 0.96010
# Epoch:    49, Train Error: 0.09965, Validation Error: 0.11428 - Test Accuracy: 0.96070

# %% [markdown]
# ## Analysis with Graph

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Draw Graph about Error Values & Accuracy Values
def draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list):
    # Draw Error Values and Accuracy
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list[1:], train_error_list[1:], 'r', label='Train')
    plt.plot(epoch_list[1:], validation_error_list[1:], 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list[1:], test_accuracy_list[1:], 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(0.0, 1.0, 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.show()

draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list)
    
def draw_false_prediction(diff_index_list):
    fig = plt.figure(figsize=(20, 5))
    for i in range(5):
        j = diff_index_list[i]
        print("False Prediction Index: %s, Prediction: %s, Ground Truth: %s" % (j, prediction[j], ground_truth[j]))
        img = np.array(img_test[j])
        img.shape = (28, 28)
        plt.subplot(150 + (i+1))
        plt.imshow(img, cmap='gray')
        
prediction = np.argmax(network.predict(img_test), axis=1)
ground_truth = np.argmax(label_test, axis=1)
        
print(prediction)
print(ground_truth)

diff_index_list = []
for i in range(len(img_test)):
    if (prediction[i] != ground_truth[i]):
        diff_index_list.append(i)

print("Total Test Image: {0}, Number of False Prediction: {1}".format(len(img_test), len(diff_index_list)))
print("Test Accuracy:", float(len(img_test) - len(diff_index_list)) / float(len(img_test)))
draw_false_prediction(diff_index_list)
# Out:
# [7 2 1 ..., 4 5 6]
# [7 2 1 ..., 4 5 6]
# Total Test Image: 10000, Number of False Prediction: 393
# Test Accuracy: 0.9607
# False Prediction Index: 151, Prediction: 8, Ground Truth: 9
# False Prediction Index: 233, Prediction: 7, Ground Truth: 8
# False Prediction Index: 241, Prediction: 5, Ground Truth: 9
# False Prediction Index: 247, Prediction: 6, Ground Truth: 4
# False Prediction Index: 259, Prediction: 0, Ground Truth: 6
