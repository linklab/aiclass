# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/Users/yhhan/git/aiclass/0.Professor/")

import tensorflux.graph as tfg
import tensorflux.Multi_Layer_Network as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff

# %%
"""
    (affine0 - batch_normal0 - relu0 - dropout0) - 
    (affine1 - batch_normal1 - relu1 - dropout1) - affine2 - softmax (output)
"""
input_size = 784
hidden_layer0_size = 128
hidden_layer1_size = 128
dropout_ratio0 = 0.5
dropout_ratio1 = 0.5
output_size = 10

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

n = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer0_size, hidden_layer1_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    use_batch_normalization=True,
    use_dropout=True,
    dropout_ratio_list=[dropout_ratio0, dropout_ratio1],
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    # initializer=tfe.Initializer.Xavier.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
# Out:
# Multi Layer Network Model - ID: BB03WPTM

# %%
n.draw_and_show(figsize=(20, 10))

# %%
data = mnist.MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)
#data = mnist.Fashion_MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)

# %%
forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
#print(forward_final_output.shape)
print("Initial Accuracy", tff.accuracy(forward_final_output, data.test_target))

batch_size = 1000
#%timeit -n1 -r1 n.learning(
n.learning(
    max_epoch=10, 
    data=data, 
    batch_size=batch_size, 
    print_period=1, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()

forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
print("Post-learning Accuracy", tff.accuracy(forward_final_output, data.test_target))
# Out:
# Initial Accuracy 0.095
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.30258 - Validation Error:2.30258 - Test Accuracy:0.14220 <== Minimal Val. Error
# Fold:  0
# Epoch   1 Completed - Train Error:2.30128 - Validation Error:2.30151 - Test Accuracy:0.11350 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:2.29725 - Validation Error:2.29676 - Test Accuracy:0.11350 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:2.08310 - Validation Error:2.07004 - Test Accuracy:0.45520 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:1.36117 - Validation Error:1.32967 - Test Accuracy:0.60580 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.78712 - Validation Error:0.76450 - Test Accuracy:0.87970 <== Minimal Val. Error
# Epoch   6 Completed - Train Error:0.41524 - Validation Error:0.41160 - Test Accuracy:0.92980 <== Minimal Val. Error
# Epoch   7 Completed - Train Error:0.31552 - Validation Error:0.27782 - Test Accuracy:0.94060 <== Minimal Val. Error
# Epoch   8 Completed - Train Error:0.20684 - Validation Error:0.21569 - Test Accuracy:0.94760 <== Minimal Val. Error
# Epoch   9 Completed - Train Error:0.20981 - Validation Error:0.18802 - Test Accuracy:0.95220 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.16810 - Validation Error:0.16797 - Test Accuracy:0.95480 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.16810 - Validation Error:0.16797 - Test Accuracy:0.95480
#
# Fold:  1
# Epoch   1 Completed - Train Error:0.14720 - Validation Error:0.16374 - Test Accuracy:0.95770 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.12342 - Validation Error:0.16019 - Test Accuracy:0.95900 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.10975 - Validation Error:0.15116 - Test Accuracy:0.95950 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.10930 - Validation Error:0.14360 - Test Accuracy:0.96170 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.12957 - Validation Error:0.13815 - Test Accuracy:0.96190 <== Minimal Val. Error
# Epoch   6 Completed - Train Error:0.09889 - Validation Error:0.14370 - Test Accuracy:0.96070
# Epoch   7 Completed - Train Error:0.12711 - Validation Error:0.13722 - Test Accuracy:0.96280 <== Minimal Val. Error
# Epoch   8 Completed - Train Error:0.12427 - Validation Error:0.13320 - Test Accuracy:0.96390 <== Minimal Val. Error
# Epoch   9 Completed - Train Error:0.09180 - Validation Error:0.13176 - Test Accuracy:0.96460 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.10563 - Validation Error:0.12854 - Test Accuracy:0.96390 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  1 & Epoch: 10) - Train Error:0.10563 - Validation Error:0.12854 - Test Accuracy:0.96390
#
# Fold:  2
# Epoch   1 Completed - Train Error:0.07515 - Validation Error:0.10355 - Test Accuracy:0.96580 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.09349 - Validation Error:0.10502 - Test Accuracy:0.96680
# Epoch   3 Completed - Train Error:0.09453 - Validation Error:0.10605 - Test Accuracy:0.96670
# Epoch   4 Completed - Train Error:0.06963 - Validation Error:0.11087 - Test Accuracy:0.96520
# Epoch   5 Completed - Train Error:0.06667 - Validation Error:0.10747 - Test Accuracy:0.96570
# Epoch   6 Completed - Train Error:0.09331 - Validation Error:0.10844 - Test Accuracy:0.96560
# Epoch   7 Completed - Train Error:0.08128 - Validation Error:0.11070 - Test Accuracy:0.96690
# Epoch   8 Completed - Train Error:0.08628 - Validation Error:0.10762 - Test Accuracy:0.96550
# Epoch   9 Completed - Train Error:0.07973 - Validation Error:0.11234 - Test Accuracy:0.96760
# Epoch  10 Completed - Train Error:0.06888 - Validation Error:0.10788 - Test Accuracy:0.96770
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 21 (Fold:  2 & Epoch:  1) - Train Error:0.07515 - Validation Error:0.10355 - Test Accuracy:0.96580
#
# Fold:  3
# Epoch   1 Completed - Train Error:0.05047 - Validation Error:0.06577 - Test Accuracy:0.96850 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.05743 - Validation Error:0.07013 - Test Accuracy:0.96710
# Epoch   3 Completed - Train Error:0.05924 - Validation Error:0.06845 - Test Accuracy:0.96670
# Epoch   4 Completed - Train Error:0.06491 - Validation Error:0.07271 - Test Accuracy:0.96770
# Epoch   5 Completed - Train Error:0.06283 - Validation Error:0.07687 - Test Accuracy:0.96900
# Epoch   6 Completed - Train Error:0.07962 - Validation Error:0.07448 - Test Accuracy:0.96870
# Epoch   7 Completed - Train Error:0.06152 - Validation Error:0.07380 - Test Accuracy:0.96810
# Epoch   8 Completed - Train Error:0.06191 - Validation Error:0.07800 - Test Accuracy:0.96880
# Epoch   9 Completed - Train Error:0.05212 - Validation Error:0.07754 - Test Accuracy:0.97060
# Epoch  10 Completed - Train Error:0.05335 - Validation Error:0.08013 - Test Accuracy:0.96890
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.05047 - Validation Error:0.06577 - Test Accuracy:0.96850
#
# Fold:  4
# Epoch   1 Completed - Train Error:0.05721 - Validation Error:0.05817 - Test Accuracy:0.96990 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.05779 - Validation Error:0.06105 - Test Accuracy:0.96890
# Epoch   3 Completed - Train Error:0.04152 - Validation Error:0.06279 - Test Accuracy:0.96950
# Epoch   4 Completed - Train Error:0.04007 - Validation Error:0.06549 - Test Accuracy:0.96780
# Epoch   5 Completed - Train Error:0.04788 - Validation Error:0.06747 - Test Accuracy:0.96870
# Epoch   6 Completed - Train Error:0.05640 - Validation Error:0.07121 - Test Accuracy:0.96920
# Epoch   7 Completed - Train Error:0.05050 - Validation Error:0.07255 - Test Accuracy:0.96810
# Epoch   8 Completed - Train Error:0.07521 - Validation Error:0.06998 - Test Accuracy:0.96920
# Epoch   9 Completed - Train Error:0.03963 - Validation Error:0.07176 - Test Accuracy:0.96880
# Epoch  10 Completed - Train Error:0.05791 - Validation Error:0.07503 - Test Accuracy:0.96870
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.05721 - Validation Error:0.05817 - Test Accuracy:0.96990
#
# Fold:  5
# Epoch   1 Completed - Train Error:0.06163 - Validation Error:0.06126 - Test Accuracy:0.97000
# Epoch   2 Completed - Train Error:0.05351 - Validation Error:0.06521 - Test Accuracy:0.96910
# Epoch   3 Completed - Train Error:0.06178 - Validation Error:0.06777 - Test Accuracy:0.96890
# Epoch   4 Completed - Train Error:0.04104 - Validation Error:0.06947 - Test Accuracy:0.96960
# Epoch   5 Completed - Train Error:0.03666 - Validation Error:0.07118 - Test Accuracy:0.97010
# Epoch   6 Completed - Train Error:0.06144 - Validation Error:0.07334 - Test Accuracy:0.96910
# Epoch   7 Completed - Train Error:0.03609 - Validation Error:0.07692 - Test Accuracy:0.96890
# Epoch   8 Completed - Train Error:0.04766 - Validation Error:0.07535 - Test Accuracy:0.96960
# Epoch   9 Completed - Train Error:0.05457 - Validation Error:0.07728 - Test Accuracy:0.97040
# Epoch  10 Completed - Train Error:0.04371 - Validation Error:0.07777 - Test Accuracy:0.97040
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.05721 - Validation Error:0.05817 - Test Accuracy:0.96990
#
# Fold:  6
# Epoch   1 Completed - Train Error:0.04202 - Validation Error:0.04530 - Test Accuracy:0.96910 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.05254 - Validation Error:0.04795 - Test Accuracy:0.97030
# Epoch   3 Completed - Train Error:0.04061 - Validation Error:0.04992 - Test Accuracy:0.96960
# Epoch   4 Completed - Train Error:0.02826 - Validation Error:0.04985 - Test Accuracy:0.97030
# Epoch   5 Completed - Train Error:0.05712 - Validation Error:0.05261 - Test Accuracy:0.97070
# Epoch   6 Completed - Train Error:0.03120 - Validation Error:0.05322 - Test Accuracy:0.97040
# Epoch   7 Completed - Train Error:0.04314 - Validation Error:0.05466 - Test Accuracy:0.97050
# Epoch   8 Completed - Train Error:0.04817 - Validation Error:0.05770 - Test Accuracy:0.96980
# Epoch   9 Completed - Train Error:0.03455 - Validation Error:0.05530 - Test Accuracy:0.97030
# Epoch  10 Completed - Train Error:0.06967 - Validation Error:0.06035 - Test Accuracy:0.96920
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 61 (Fold:  6 & Epoch:  1) - Train Error:0.04202 - Validation Error:0.04530 - Test Accuracy:0.96910
#
# Fold:  7
# Epoch   1 Completed - Train Error:0.04052 - Validation Error:0.05398 - Test Accuracy:0.96960
# Epoch   2 Completed - Train Error:0.04442 - Validation Error:0.05230 - Test Accuracy:0.97030
# Epoch   3 Completed - Train Error:0.03671 - Validation Error:0.05651 - Test Accuracy:0.97080
# Epoch   4 Completed - Train Error:0.05594 - Validation Error:0.06012 - Test Accuracy:0.97000
# Epoch   5 Completed - Train Error:0.04508 - Validation Error:0.06037 - Test Accuracy:0.96990
# Epoch   6 Completed - Train Error:0.05607 - Validation Error:0.06049 - Test Accuracy:0.97170
# Epoch   7 Completed - Train Error:0.03554 - Validation Error:0.06339 - Test Accuracy:0.97060
# Epoch   8 Completed - Train Error:0.02871 - Validation Error:0.06499 - Test Accuracy:0.97020
# Epoch   9 Completed - Train Error:0.02698 - Validation Error:0.06660 - Test Accuracy:0.96960
# Epoch  10 Completed - Train Error:0.04781 - Validation Error:0.06688 - Test Accuracy:0.96990
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 61 (Fold:  6 & Epoch:  1) - Train Error:0.04202 - Validation Error:0.04530 - Test Accuracy:0.96910
#
# Fold:  8
# Epoch   1 Completed - Train Error:0.04090 - Validation Error:0.04498 - Test Accuracy:0.97050 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.05645 - Validation Error:0.04867 - Test Accuracy:0.97000
# Epoch   3 Completed - Train Error:0.03268 - Validation Error:0.04747 - Test Accuracy:0.97000
# Epoch   4 Completed - Train Error:0.03186 - Validation Error:0.04837 - Test Accuracy:0.97060
# Epoch   5 Completed - Train Error:0.04544 - Validation Error:0.05342 - Test Accuracy:0.96940
# Epoch   6 Completed - Train Error:0.03442 - Validation Error:0.05286 - Test Accuracy:0.97090
# Epoch   7 Completed - Train Error:0.03410 - Validation Error:0.05837 - Test Accuracy:0.96920
# Epoch   8 Completed - Train Error:0.02788 - Validation Error:0.05360 - Test Accuracy:0.96990
# Epoch   9 Completed - Train Error:0.03010 - Validation Error:0.06148 - Test Accuracy:0.97090
# Epoch  10 Completed - Train Error:0.02168 - Validation Error:0.06258 - Test Accuracy:0.97130
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.04090 - Validation Error:0.04498 - Test Accuracy:0.97050
#
# Fold:  9
# Epoch   1 Completed - Train Error:0.02747 - Validation Error:0.03700 - Test Accuracy:0.96960 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.03452 - Validation Error:0.04525 - Test Accuracy:0.97060
# Epoch   3 Completed - Train Error:0.04155 - Validation Error:0.04691 - Test Accuracy:0.97010
# Epoch   4 Completed - Train Error:0.03553 - Validation Error:0.04433 - Test Accuracy:0.96940
# Epoch   5 Completed - Train Error:0.03636 - Validation Error:0.04779 - Test Accuracy:0.96960
# Epoch   6 Completed - Train Error:0.03532 - Validation Error:0.05036 - Test Accuracy:0.96940
# Epoch   7 Completed - Train Error:0.03398 - Validation Error:0.04980 - Test Accuracy:0.97040
# Epoch   8 Completed - Train Error:0.03685 - Validation Error:0.05225 - Test Accuracy:0.96990
# Epoch   9 Completed - Train Error:0.03132 - Validation Error:0.05332 - Test Accuracy:0.97010
# Epoch  10 Completed - Train Error:0.04106 - Validation Error:0.05370 - Test Accuracy:0.97080
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 91 (Fold:  9 & Epoch:  1) - Train Error:0.02747 - Validation Error:0.03700 - Test Accuracy:0.96960
#
# Fold:  10
# Epoch   1 Completed - Train Error:0.02709 - Validation Error:0.03201 - Test Accuracy:0.97100 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.03508 - Validation Error:0.03319 - Test Accuracy:0.97030
# Epoch   3 Completed - Train Error:0.02808 - Validation Error:0.03625 - Test Accuracy:0.97110
# Epoch   4 Completed - Train Error:0.02954 - Validation Error:0.03531 - Test Accuracy:0.96980
# Epoch   5 Completed - Train Error:0.02914 - Validation Error:0.03885 - Test Accuracy:0.96930
# Epoch   6 Completed - Train Error:0.04958 - Validation Error:0.03940 - Test Accuracy:0.96980
# Epoch   7 Completed - Train Error:0.02388 - Validation Error:0.03926 - Test Accuracy:0.97020
# Epoch   8 Completed - Train Error:0.02330 - Validation Error:0.04212 - Test Accuracy:0.97090
# Epoch   9 Completed - Train Error:0.02325 - Validation Error:0.04433 - Test Accuracy:0.96950
# Epoch  10 Completed - Train Error:0.03917 - Validation Error:0.04363 - Test Accuracy:0.97000
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:101 (Fold: 10 & Epoch:  1) - Train Error:0.02709 - Validation Error:0.03201 - Test Accuracy:0.97100
#
# Fold:  11
# Epoch   1 Completed - Train Error:0.02911 - Validation Error:0.02836 - Test Accuracy:0.96980 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.02695 - Validation Error:0.02838 - Test Accuracy:0.96970
# Epoch   3 Completed - Train Error:0.02788 - Validation Error:0.03306 - Test Accuracy:0.96950
# Epoch   4 Completed - Train Error:0.02256 - Validation Error:0.03414 - Test Accuracy:0.97010
# Epoch   5 Completed - Train Error:0.03401 - Validation Error:0.03384 - Test Accuracy:0.97020
# Epoch   6 Completed - Train Error:0.02042 - Validation Error:0.03280 - Test Accuracy:0.96920
# Epoch   7 Completed - Train Error:0.02319 - Validation Error:0.03542 - Test Accuracy:0.96970
# Epoch   8 Completed - Train Error:0.03795 - Validation Error:0.03720 - Test Accuracy:0.96990
# Epoch   9 Completed - Train Error:0.02182 - Validation Error:0.03659 - Test Accuracy:0.97070
# Epoch  10 Completed - Train Error:0.02279 - Validation Error:0.03790 - Test Accuracy:0.96950
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.02911 - Validation Error:0.02836 - Test Accuracy:0.96980
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --
#
# Post-learning Accuracy 0.9411

# %%
print("Epoch:{:3d}, Min Train Error:{:7.5f}, Min Validation Error:{:7.5f}, Test Accuracy:{:7.5f}".format(
    n.min_validation_error_epoch,
    n.min_train_error,
    n.min_validation_error,
    n.test_accuracy_at_min_validation_error_epoch
))

print("Mean of Min Va. Error For All Folds:{:7.5f}".format(n.mean_min_validation_error_for_all_folds))
# Out:
# Epoch:111, Min Train Error:0.02911, Min Validation Error:0.02836, Test Accuracy:0.96980
# Mean of Min Va. Error For All Folds:0.06793

# %%
n.draw_error_values_and_accuracy(figsize=(20, 5))

# %%
n.draw_false_prediction(data.test_input, data.test_target, data.labels, num=5, figsize=(20, 5))
# Out:
# False Prediction Index: 18, Prediction: Eight, Ground Truth: Three
# False Prediction Index: 33, Prediction: Zero, Ground Truth: Four
# False Prediction Index: 45, Prediction: Eight, Ground Truth: Five
# False Prediction Index: 59, Prediction: Eight, Ground Truth: Five
# False Prediction Index: 63, Prediction: Two, Ground Truth: Three

# %%
n.draw_param_description(figsize=(20, 10))

# %%
n.draw_output_description(figsize=(20, 10))
