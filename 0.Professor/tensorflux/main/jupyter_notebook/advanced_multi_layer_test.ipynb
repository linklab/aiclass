# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/Users/yhhan/git/aiclass/0.Professor/")

import tensorflux.graph as tfg
import tensorflux.Multi_Layer_Network as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff
# Out:
# 0.35.0

# %%
input_size = 784
hidden_layer1_size = 128
hidden_layer2_size = 128
output_size = 10

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

n = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    use_batch_normalization=True,
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    # initializer=tfe.Initializer.Xavier.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
# Out:
# Multi Layer Network Model - ID: LCHH5YFL

# %%
n.draw_and_show(figsize=(20, 10))

# %%
data = mnist.MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)
#data = mnist.Fashion_MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)

# %%
forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
#print(forward_final_output.shape)
print("Initial Accuracy", tff.accuracy(forward_final_output, data.test_target))

batch_size = 1000
#%timeit -n1 -r1 n.learning(
n.learning(
    max_epoch=5, 
    data=data, 
    batch_size=batch_size, 
    print_period=1, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()

forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
print("Post-learning Accuracy", tff.accuracy(forward_final_output, data.test_target))
# Out:
# Initial Accuracy 0.0958
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.30267 - Validation Error:2.30265 - Test Accuracy:0.05600 <== Minimal Val. Error
# Fold:  0
# Epoch   1 Completed - Train Error:2.29553 - Validation Error:2.29417 - Test Accuracy:0.15220 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:1.61324 - Validation Error:1.60305 - Test Accuracy:0.71020 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.49539 - Validation Error:0.47085 - Test Accuracy:0.93300 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.18332 - Validation Error:0.20089 - Test Accuracy:0.96120 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.13546 - Validation Error:0.13856 - Test Accuracy:0.96800 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:  5 (Fold:  0 & Epoch:  5) - Train Error:0.13546 - Validation Error:0.13856 - Test Accuracy:0.96800
#
# Fold:  1
# Epoch   1 Completed - Train Error:0.07947 - Validation Error:0.11581 - Test Accuracy:0.97260 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.07856 - Validation Error:0.10453 - Test Accuracy:0.97170 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.05610 - Validation Error:0.09733 - Test Accuracy:0.97310 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.04231 - Validation Error:0.09321 - Test Accuracy:0.97280 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.03224 - Validation Error:0.09337 - Test Accuracy:0.97330
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:  9 (Fold:  1 & Epoch:  4) - Train Error:0.04231 - Validation Error:0.09321 - Test Accuracy:0.97280
#
# Fold:  2
# Epoch   1 Completed - Train Error:0.05532 - Validation Error:0.04998 - Test Accuracy:0.97330 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.04702 - Validation Error:0.05053 - Test Accuracy:0.97350
# Epoch   3 Completed - Train Error:0.02809 - Validation Error:0.05215 - Test Accuracy:0.97360
# Epoch   4 Completed - Train Error:0.02225 - Validation Error:0.05000 - Test Accuracy:0.97390
# Epoch   5 Completed - Train Error:0.01575 - Validation Error:0.05182 - Test Accuracy:0.97270
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 11 (Fold:  2 & Epoch:  1) - Train Error:0.05532 - Validation Error:0.04998 - Test Accuracy:0.97330
#
# Fold:  3
# Epoch   1 Completed - Train Error:0.02241 - Validation Error:0.02732 - Test Accuracy:0.97410 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.01618 - Validation Error:0.02857 - Test Accuracy:0.97430
# Epoch   3 Completed - Train Error:0.01187 - Validation Error:0.02833 - Test Accuracy:0.97390
# Epoch   4 Completed - Train Error:0.01687 - Validation Error:0.02876 - Test Accuracy:0.97480
# Epoch   5 Completed - Train Error:0.01146 - Validation Error:0.02637 - Test Accuracy:0.97580 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  3 & Epoch:  5) - Train Error:0.01146 - Validation Error:0.02637 - Test Accuracy:0.97580
#
# Fold:  4
# Epoch   1 Completed - Train Error:0.00871 - Validation Error:0.01832 - Test Accuracy:0.97520 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00679 - Validation Error:0.01474 - Test Accuracy:0.97620 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.00436 - Validation Error:0.01226 - Test Accuracy:0.97650 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.00515 - Validation Error:0.01346 - Test Accuracy:0.97560
# Epoch   5 Completed - Train Error:0.00334 - Validation Error:0.01221 - Test Accuracy:0.97660 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 25 (Fold:  4 & Epoch:  5) - Train Error:0.00334 - Validation Error:0.01221 - Test Accuracy:0.97660
#
# Fold:  5
# Epoch   1 Completed - Train Error:0.00661 - Validation Error:0.00832 - Test Accuracy:0.97510 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00567 - Validation Error:0.00783 - Test Accuracy:0.97550 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.00346 - Validation Error:0.00669 - Test Accuracy:0.97660 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.00291 - Validation Error:0.00649 - Test Accuracy:0.97640 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.00287 - Validation Error:0.00683 - Test Accuracy:0.97780
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 29 (Fold:  5 & Epoch:  4) - Train Error:0.00291 - Validation Error:0.00649 - Test Accuracy:0.97640
#
# Fold:  6
# Epoch   1 Completed - Train Error:0.00252 - Validation Error:0.00255 - Test Accuracy:0.97640 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00231 - Validation Error:0.00235 - Test Accuracy:0.97710 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.00152 - Validation Error:0.00234 - Test Accuracy:0.97760 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.00189 - Validation Error:0.00239 - Test Accuracy:0.97750
# Epoch   5 Completed - Train Error:0.00225 - Validation Error:0.00240 - Test Accuracy:0.97740
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 33 (Fold:  6 & Epoch:  3) - Train Error:0.00152 - Validation Error:0.00234 - Test Accuracy:0.97760
#
# Fold:  7
# Epoch   1 Completed - Train Error:0.00138 - Validation Error:0.00172 - Test Accuracy:0.97760 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00147 - Validation Error:0.00171 - Test Accuracy:0.97750 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.00101 - Validation Error:0.00179 - Test Accuracy:0.97740
# Epoch   4 Completed - Train Error:0.00101 - Validation Error:0.00179 - Test Accuracy:0.97730
# Epoch   5 Completed - Train Error:0.00122 - Validation Error:0.00184 - Test Accuracy:0.97740
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 37 (Fold:  7 & Epoch:  2) - Train Error:0.00147 - Validation Error:0.00171 - Test Accuracy:0.97750
#
# Fold:  8
# Epoch   1 Completed - Train Error:0.00112 - Validation Error:0.00095 - Test Accuracy:0.97740 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00093 - Validation Error:0.00098 - Test Accuracy:0.97790
# Epoch   3 Completed - Train Error:0.00099 - Validation Error:0.00102 - Test Accuracy:0.97780
# Epoch   4 Completed - Train Error:0.00079 - Validation Error:0.00105 - Test Accuracy:0.97810
# Epoch   5 Completed - Train Error:0.00083 - Validation Error:0.00109 - Test Accuracy:0.97840
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  8 & Epoch:  1) - Train Error:0.00112 - Validation Error:0.00095 - Test Accuracy:0.97740
#
# Fold:  9
# Epoch   1 Completed - Train Error:0.00080 - Validation Error:0.00090 - Test Accuracy:0.97730 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00097 - Validation Error:0.00096 - Test Accuracy:0.97750
# Epoch   3 Completed - Train Error:0.00074 - Validation Error:0.00101 - Test Accuracy:0.97730
# Epoch   4 Completed - Train Error:0.00090 - Validation Error:0.00105 - Test Accuracy:0.97720
# Epoch   5 Completed - Train Error:0.00069 - Validation Error:0.00110 - Test Accuracy:0.97720
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 46 (Fold:  9 & Epoch:  1) - Train Error:0.00080 - Validation Error:0.00090 - Test Accuracy:0.97730
#
# Fold:  10
# Epoch   1 Completed - Train Error:0.00075 - Validation Error:0.00067 - Test Accuracy:0.97750 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00043 - Validation Error:0.00067 - Test Accuracy:0.97750 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.00057 - Validation Error:0.00070 - Test Accuracy:0.97770
# Epoch   4 Completed - Train Error:0.00061 - Validation Error:0.00072 - Test Accuracy:0.97740
# Epoch   5 Completed - Train Error:0.00038 - Validation Error:0.00074 - Test Accuracy:0.97770
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 52 (Fold: 10 & Epoch:  2) - Train Error:0.00043 - Validation Error:0.00067 - Test Accuracy:0.97750
#
# Fold:  11
# Epoch   1 Completed - Train Error:0.00087 - Validation Error:0.00063 - Test Accuracy:0.97760 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.18133 - Validation Error:0.13290 - Test Accuracy:0.94720
# Epoch   3 Completed - Train Error:0.05174 - Validation Error:0.06773 - Test Accuracy:0.96800
# Epoch   4 Completed - Train Error:0.01358 - Validation Error:0.04121 - Test Accuracy:0.97130
# Epoch   5 Completed - Train Error:0.00668 - Validation Error:0.02849 - Test Accuracy:0.97520
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 56 (Fold: 11 & Epoch:  1) - Train Error:0.00087 - Validation Error:0.00063 - Test Accuracy:0.97760
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --
#
# Post-learning Accuracy 0.9775

# %%
print("Epoch:{:3d}, Min Train Error:{:7.5f}, Min Validation Error:{:7.5f}, Test Accuracy:{:7.5f}".format(
    n.min_validation_error_epoch,
    n.min_train_error,
    n.min_validation_error,
    n.test_accuracy_at_min_validation_error_epoch
))

print("Mean of Min Va. Error For All Folds:{:7.5f}".format(n.mean_min_validation_error_for_all_folds))
# Out:
# Epoch: 56, Min Train Error:0.00087, Min Validation Error:0.00063, Test Accuracy:0.97760
# Mean of Min Va. Error For All Folds:0.02783

# %%
n.draw_error_values_and_accuracy(figsize=(20, 5))

# %%
n.draw_false_prediction(data.test_input, data.test_target, data.labels, num=5, figsize=(20, 5))
# Out:
# False Prediction Index: 18, Prediction: Five, Ground Truth: Three
# False Prediction Index: 115, Prediction: Nine, Ground Truth: Four
# False Prediction Index: 124, Prediction: Four, Ground Truth: Seven
# False Prediction Index: 149, Prediction: Nine, Ground Truth: Two
# False Prediction Index: 247, Prediction: Two, Ground Truth: Four

# %%
n.draw_param_description(figsize=(20, 10))

# %%
n.draw_output_description(figsize=(20, 10))
