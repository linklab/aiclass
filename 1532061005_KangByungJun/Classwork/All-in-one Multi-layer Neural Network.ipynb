# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import math
import tensorflow as tf

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

batch_size = 100
training_epochs = 100
learning_rate = 0.05

epoch_list = []
train_error_list = []
validation_error_list = []
test_accuracy_list = []
diff_index_list = []

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_hidden_1 = 128 # 1st layer number of features
n_hidden_2 = 128 # 2nd layer number of features
n_classes = 10 # MNIST total classes (0-9 digits)
    
# Data Preparation
x = tf.placeholder(tf.float32, [None, n_input])
y_target = tf.placeholder(tf.float32, [None, n_classes])

# Model Construction
# Store layers weight & bias
weights = {
    'W1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, n_classes]))
}

biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# 1st Hidden layer with RELU activation
u2 = tf.matmul(x, weights['W1']) + biases['b1']
z2 = tf.nn.relu(u2)

# 2ndHidden layer with RELU activation
u3 = tf.matmul(z2, weights['W2']) + biases['b2']
z3 = tf.nn.relu(u3)

# Output layer with linear activation
u_out = tf.matmul(z3, weights['out']) + biases['out']

# Target Setup
error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=u_out, labels=y_target))
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(error)

# Accuracy   
prediction_and_ground_truth = tf.equal(tf.argmax(u_out, 1), tf.argmax(y_target, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_and_ground_truth, tf.float32))

def draw_error_values_and_accuracy():
    # Draw Error Values and Accuracy
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list[1:], train_error_list[1:], 'r', label='Train')
    plt.plot(epoch_list[1:], validation_error_list[1:], 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list[1:], test_accuracy_list[1:], 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(0.0, 1.0, 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.show()
    
def draw_false_prediction():
    fig = plt.figure(figsize=(20, 5))
    for i in range(5):
        j = diff_index_list[i]
        print("False Prediction Index: %s, Prediction: %s, Ground Truth: %s" % (j, prediction[j], ground_truth[j]))
        img = np.array(mnist.test.images[j])
        img.shape = (28, 28)
        plt.subplot(150 + (i+1))
        plt.imshow(img, cmap='gray')
    
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    
    total_batch = int(math.ceil(mnist.train.num_examples/float(batch_size)))
    print("Total batch: %d" % total_batch)    

    for epoch in range(training_epochs):
        epoch_list.append(epoch)
        # Train Error Value
        train_error_value = sess.run(error, feed_dict={x: mnist.train.images, y_target: mnist.train.labels})
        train_error_list.append(train_error_value)
        
        validation_error_value = sess.run(error, feed_dict={x: mnist.validation.images, y_target: mnist.validation.labels})
        validation_error_list.append(validation_error_value)
        
        test_accuracy_value = sess.run(accuracy, feed_dict={x: mnist.test.images, y_target: mnist.test.labels})
        test_accuracy_list.append(test_accuracy_value) 
        print("Epoch: {0:2d}, Train Error: {1:0.5f}, Validation Error: {2:0.5f}, Test Accuracy: {3:0.5f}".format(epoch, train_error_value, validation_error_value, test_accuracy_value))
        
        for i in range(total_batch):
            batch_images, batch_labels = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={x: batch_images, y_target: batch_labels})
    

    # Draw Graph about Error Values & Accuracy Values
    draw_error_values_and_accuracy()
    
    # False Prediction Profile
    prediction = sess.run(tf.argmax(u_out, 1), feed_dict={x:mnist.test.images})
    ground_truth = sess.run(tf.argmax(y_target, 1), feed_dict={y_target:mnist.test.labels})

    print(prediction)
    print(ground_truth)

    for i in range(mnist.test.num_examples):
        if (prediction[i] != ground_truth[i]):
            diff_index_list.append(i)
            
    print("Number of False Prediction:", len(diff_index_list))
    draw_false_prediction()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Total batch: 550
# Epoch:  0, Train Error: 638.15387, Validation Error: 622.03351, Test Accuracy: 0.10900
# Epoch:  1, Train Error: 1.58024, Validation Error: 1.59473, Test Accuracy: 0.50040
# Epoch:  2, Train Error: 1.28378, Validation Error: 1.31888, Test Accuracy: 0.57980
# Epoch:  3, Train Error: 1.31961, Validation Error: 1.35457, Test Accuracy: 0.58480
# Epoch:  4, Train Error: 1.01381, Validation Error: 1.07104, Test Accuracy: 0.67320
# Epoch:  5, Train Error: 0.98843, Validation Error: 1.06293, Test Accuracy: 0.66740
# Epoch:  6, Train Error: 0.84374, Validation Error: 0.91143, Test Accuracy: 0.73820
# Epoch:  7, Train Error: 0.77791, Validation Error: 0.83182, Test Accuracy: 0.75050
# Epoch:  8, Train Error: 0.75185, Validation Error: 0.80926, Test Accuracy: 0.76260
# Epoch:  9, Train Error: 0.88134, Validation Error: 0.94072, Test Accuracy: 0.71180
# Epoch: 10, Train Error: 0.73186, Validation Error: 0.77019, Test Accuracy: 0.77290
# Epoch: 11, Train Error: 0.65514, Validation Error: 0.69420, Test Accuracy: 0.79640
# Epoch: 12, Train Error: 0.61699, Validation Error: 0.66953, Test Accuracy: 0.81420
# Epoch: 13, Train Error: 0.68418, Validation Error: 0.72186, Test Accuracy: 0.76130
# Epoch: 14, Train Error: 0.56196, Validation Error: 0.61145, Test Accuracy: 0.83090
# Epoch: 15, Train Error: 0.57122, Validation Error: 0.62002, Test Accuracy: 0.83570
# Epoch: 16, Train Error: 0.55528, Validation Error: 0.59755, Test Accuracy: 0.83610
# Epoch: 17, Train Error: 0.52422, Validation Error: 0.57360, Test Accuracy: 0.84360
# Epoch: 18, Train Error: 0.53082, Validation Error: 0.58558, Test Accuracy: 0.84150
# Epoch: 19, Train Error: 0.49309, Validation Error: 0.55097, Test Accuracy: 0.85390
# Epoch: 20, Train Error: 0.47785, Validation Error: 0.53156, Test Accuracy: 0.86070
# Epoch: 21, Train Error: 0.46224, Validation Error: 0.51739, Test Accuracy: 0.86430
# Epoch: 22, Train Error: 0.45431, Validation Error: 0.51917, Test Accuracy: 0.86830
# Epoch: 23, Train Error: 0.45781, Validation Error: 0.51175, Test Accuracy: 0.86130
# Epoch: 24, Train Error: 0.45514, Validation Error: 0.51753, Test Accuracy: 0.86240
# Epoch: 25, Train Error: 0.48527, Validation Error: 0.54656, Test Accuracy: 0.83310
# Epoch: 26, Train Error: 0.41760, Validation Error: 0.49944, Test Accuracy: 0.87450
# Epoch: 27, Train Error: 0.40505, Validation Error: 0.47936, Test Accuracy: 0.88040
# Epoch: 28, Train Error: 0.39550, Validation Error: 0.46075, Test Accuracy: 0.88470
# Epoch: 29, Train Error: 0.38589, Validation Error: 0.45420, Test Accuracy: 0.88580
# Epoch: 30, Train Error: 0.40400, Validation Error: 0.47973, Test Accuracy: 0.87600
# Epoch: 31, Train Error: 0.38748, Validation Error: 0.45346, Test Accuracy: 0.88120
# Epoch: 32, Train Error: 0.37082, Validation Error: 0.45051, Test Accuracy: 0.88710
# Epoch: 33, Train Error: 0.39891, Validation Error: 0.46824, Test Accuracy: 0.88240
# Epoch: 34, Train Error: 0.37004, Validation Error: 0.44969, Test Accuracy: 0.89030
# Epoch: 35, Train Error: 0.35788, Validation Error: 0.42959, Test Accuracy: 0.89110
# Epoch: 36, Train Error: 0.35364, Validation Error: 0.42895, Test Accuracy: 0.89110
# Epoch: 37, Train Error: 0.36188, Validation Error: 0.43289, Test Accuracy: 0.89050
# Epoch: 38, Train Error: 0.34082, Validation Error: 0.41357, Test Accuracy: 0.89590
# Epoch: 39, Train Error: 0.33116, Validation Error: 0.40729, Test Accuracy: 0.89820
# Epoch: 40, Train Error: 0.32858, Validation Error: 0.40978, Test Accuracy: 0.89860
# Epoch: 41, Train Error: 0.33623, Validation Error: 0.40712, Test Accuracy: 0.89670
# Epoch: 42, Train Error: 0.31505, Validation Error: 0.40262, Test Accuracy: 0.90120
# Epoch: 43, Train Error: 0.31918, Validation Error: 0.40036, Test Accuracy: 0.90370
# Epoch: 44, Train Error: 0.31883, Validation Error: 0.40541, Test Accuracy: 0.89970
# Epoch: 45, Train Error: 0.35575, Validation Error: 0.43274, Test Accuracy: 0.89280
# Epoch: 46, Train Error: 0.30324, Validation Error: 0.39175, Test Accuracy: 0.90420
# Epoch: 47, Train Error: 0.30458, Validation Error: 0.38687, Test Accuracy: 0.90730
# Epoch: 48, Train Error: 0.32120, Validation Error: 0.39396, Test Accuracy: 0.90110
# Epoch: 49, Train Error: 0.29489, Validation Error: 0.38433, Test Accuracy: 0.90610
# Epoch: 50, Train Error: 0.28996, Validation Error: 0.38077, Test Accuracy: 0.90840
# Epoch: 51, Train Error: 0.29730, Validation Error: 0.38428, Test Accuracy: 0.90580
# Epoch: 52, Train Error: 0.29140, Validation Error: 0.37974, Test Accuracy: 0.90730
# Epoch: 53, Train Error: 0.28173, Validation Error: 0.37402, Test Accuracy: 0.91290
# Epoch: 54, Train Error: 0.31098, Validation Error: 0.39503, Test Accuracy: 0.90140
# Epoch: 55, Train Error: 0.29597, Validation Error: 0.37648, Test Accuracy: 0.90610
# Epoch: 56, Train Error: 0.26979, Validation Error: 0.36264, Test Accuracy: 0.91380
# Epoch: 57, Train Error: 0.26898, Validation Error: 0.35932, Test Accuracy: 0.91400
# Epoch: 58, Train Error: 0.26815, Validation Error: 0.35960, Test Accuracy: 0.91480
# Epoch: 59, Train Error: 0.27518, Validation Error: 0.36124, Test Accuracy: 0.91040
# Epoch: 60, Train Error: 0.33287, Validation Error: 0.42615, Test Accuracy: 0.89110
# Epoch: 61, Train Error: 0.25803, Validation Error: 0.35560, Test Accuracy: 0.91600
# Epoch: 62, Train Error: 0.27129, Validation Error: 0.36308, Test Accuracy: 0.91180
# Epoch: 63, Train Error: 0.24980, Validation Error: 0.33386, Test Accuracy: 0.91950
# Epoch: 64, Train Error: 0.25190, Validation Error: 0.34382, Test Accuracy: 0.91770
# Epoch: 65, Train Error: 0.25976, Validation Error: 0.34994, Test Accuracy: 0.91560
# Epoch: 66, Train Error: 0.25902, Validation Error: 0.34742, Test Accuracy: 0.91390
# Epoch: 67, Train Error: 0.24825, Validation Error: 0.33695, Test Accuracy: 0.91870
# Epoch: 68, Train Error: 0.26674, Validation Error: 0.35741, Test Accuracy: 0.90960
# Epoch: 69, Train Error: 0.24427, Validation Error: 0.33313, Test Accuracy: 0.91920
# Epoch: 70, Train Error: 0.24423, Validation Error: 0.32864, Test Accuracy: 0.91800
# Epoch: 71, Train Error: 0.23815, Validation Error: 0.32922, Test Accuracy: 0.92120
# Epoch: 72, Train Error: 0.23476, Validation Error: 0.32917, Test Accuracy: 0.92090
# Epoch: 73, Train Error: 0.23535, Validation Error: 0.32746, Test Accuracy: 0.92160
# Epoch: 74, Train Error: 0.24381, Validation Error: 0.34068, Test Accuracy: 0.91920
# Epoch: 75, Train Error: 0.23313, Validation Error: 0.32363, Test Accuracy: 0.92280
# Epoch: 76, Train Error: 0.24815, Validation Error: 0.34245, Test Accuracy: 0.91450
# Epoch: 77, Train Error: 0.22749, Validation Error: 0.32551, Test Accuracy: 0.92190
# Epoch: 78, Train Error: 0.22583, Validation Error: 0.32335, Test Accuracy: 0.92290
# Epoch: 79, Train Error: 0.22420, Validation Error: 0.32268, Test Accuracy: 0.92590
# Epoch: 80, Train Error: 0.22461, Validation Error: 0.32011, Test Accuracy: 0.92420
# Epoch: 81, Train Error: 0.23778, Validation Error: 0.33461, Test Accuracy: 0.91950
# Epoch: 82, Train Error: 0.22138, Validation Error: 0.31989, Test Accuracy: 0.92530
# Epoch: 83, Train Error: 0.21847, Validation Error: 0.31035, Test Accuracy: 0.92660
# Epoch: 84, Train Error: 0.21560, Validation Error: 0.30757, Test Accuracy: 0.92780
# Epoch: 85, Train Error: 0.23686, Validation Error: 0.33112, Test Accuracy: 0.91870
# Epoch: 86, Train Error: 0.21468, Validation Error: 0.31371, Test Accuracy: 0.92440
# Epoch: 87, Train Error: 0.21014, Validation Error: 0.30979, Test Accuracy: 0.92670
# Epoch: 88, Train Error: 0.21403, Validation Error: 0.31633, Test Accuracy: 0.92550
# Epoch: 89, Train Error: 0.21139, Validation Error: 0.31395, Test Accuracy: 0.92740
# Epoch: 90, Train Error: 0.21347, Validation Error: 0.31423, Test Accuracy: 0.92680
# Epoch: 91, Train Error: 0.21511, Validation Error: 0.31214, Test Accuracy: 0.92530
# Epoch: 92, Train Error: 0.20695, Validation Error: 0.30774, Test Accuracy: 0.92660
# Epoch: 93, Train Error: 0.20402, Validation Error: 0.31095, Test Accuracy: 0.92870
# Epoch: 94, Train Error: 0.20247, Validation Error: 0.30876, Test Accuracy: 0.92860
# Epoch: 95, Train Error: 0.20300, Validation Error: 0.30958, Test Accuracy: 0.92740
# Epoch: 96, Train Error: 0.19530, Validation Error: 0.29601, Test Accuracy: 0.93130
# Epoch: 97, Train Error: 0.19874, Validation Error: 0.30220, Test Accuracy: 0.93050
# Epoch: 98, Train Error: 0.19797, Validation Error: 0.30021, Test Accuracy: 0.92920
# Epoch: 99, Train Error: 0.19588, Validation Error: 0.30304, Test Accuracy: 0.93070
# [7 2 1 ..., 4 5 6]
# [7 2 1 ..., 4 5 6]
# Number of False Prediction: 700
# False Prediction Index: 8, Prediction: 6, Ground Truth: 5
# False Prediction Index: 33, Prediction: 5, Ground Truth: 4
# False Prediction Index: 38, Prediction: 3, Ground Truth: 2
# False Prediction Index: 61, Prediction: 2, Ground Truth: 8
# False Prediction Index: 65, Prediction: 9, Ground Truth: 4
