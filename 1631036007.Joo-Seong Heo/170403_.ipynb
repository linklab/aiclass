# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import math
import tensorflow as tf
print(tf.__version__)

# %matplotlib inline
# Out:
# 0.10.0rc0

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print(type(mnist.train.images), mnist.train.images.shape)
print(type(mnist.train.labels), mnist.train.labels.shape)
# Out:
# (<type 'numpy.ndarray'>, (55000, 784))
# (<type 'numpy.ndarray'>, (55000, 10))

# %%
fig = plt.figure(figsize=(20, 5))
for i in range(5):
    img = np.array(mnist.train.images[i])
    img.shape = (28, 28)
    plt.subplot(150 + (i+1))
    plt.imshow(img, cmap='gray')

# %%
print(type(mnist.validation.images), mnist.validation.images.shape)
print(type(mnist.validation.labels), mnist.validation.labels.shape)
# Out:
# (<type 'numpy.ndarray'>, (5000, 784))
# (<type 'numpy.ndarray'>, (5000, 10))

# %%
print(type(mnist.test.images), mnist.test.images.shape)
print(type(mnist.test.labels), mnist.test.labels.shape)
# Out:
# (<type 'numpy.ndarray'>, (10000, 784))
# (<type 'numpy.ndarray'>, (10000, 10))

# %%
W_ = np.array([[1, 2, 3], [4, 5, 6]])  #shape of W: (2, 3)
x_ = np.array([[1, 2]])                #shape of x: (1, 2)
xW_ = np.dot(x_, W_)                     #shape of xW: (1, 3)
print(W_.shape, x_.shape, xW_.shape)
print(xW_)

print()

b_ = np.array([10, 20, 30])            #shape of b: (3,)
u_ = xW_ + b_                            #shape of u: (1, 3) 
print(b_.shape, u_.shape)
print(u_)
# Out:
# ((2, 3), (1, 2), (1, 3))
# [[ 9 12 15]]
# ()
# ((3,), (1, 3))
# [[19 32 45]]

# %%
batch_images, batch_labels = mnist.train.next_batch(100)
print(batch_images.shape)
#print batch_images
print

print(batch_labels.shape)
#print batch_labels
# Out:
# (100, 784)
#
# (100, 10)

# %%
W_ = np.array([[1, 2, 3], [4, 5, 6]])                    #shape of W: (2, 3)
x_ = np.array([[1, 2], [1, 2], [1, 2], [1, 2], [1, 2]])  #shape of x: (5, 2)
xW_ = np.dot(x_, W_)                                       #shape of xW: (5, 3)
print(W_.shape, x_.shape, xW_.shape)
print(xW_)

print()

b_ = np.array([10, 20, 30])            #shape of b: (3,)
u_ = xW_ + b_                            #shape of u: (1, 3) 
print(b_.shape, u_.shape)
print(u_)
# Out:
# ((2, 3), (5, 2), (5, 3))
# [[ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]]
# ()
# ((3,), (5, 3))
# [[19 32 45]
#  [19 32 45]
#  [19 32 45]
#  [19 32 45]
#  [19 32 45]]

# %%
x = tf.placeholder(tf.float32, [None, 784])
print("x -", x.get_shape())
# Out:
# ('x -', TensorShape([Dimension(None), Dimension(784)]))

# %%
y_target = tf.placeholder(tf.float32, [None, 10])

# %%
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))
print("W -", W.get_shape())
print("b -", b.get_shape())
# Out:
# ('W -', TensorShape([Dimension(784), Dimension(10)]))
# ('b -', TensorShape([Dimension(10)]))

# %%
u = tf.matmul(x, W) + b
print("u -", u.get_shape())
# Out:
# ('u -', TensorShape([Dimension(None), Dimension(10)]))

# %%
learning_rate = 0.05
error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=u, labels=y_target))
optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(error)

# %%
prediction_and_ground_truth = tf.equal(tf.argmax(u, 1), tf.argmax(y_target, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_and_ground_truth, tf.float32))

def draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list):
    # Draw Error Values and Accuracy
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list[1:], train_error_list[1:], 'r', label='Train')
    plt.plot(epoch_list[1:], validation_error_list[1:], 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list[1:], test_accuracy_list[1:], 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(0.0, 1.0, 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.show()
    
def draw_false_prediction(diff_index_list):
    fig = plt.figure(figsize=(20, 5))
    for i in range(5):
        j = diff_index_list[i]
        print("False Prediction Index: %s, Prediction: %s, Ground Truth: %s" % (j, prediction[j], ground_truth[j]))
        img = np.array(mnist.test.images[j])
        img.shape = (28, 28)
        plt.subplot(150 + (i+1))
        plt.imshow(img, cmap='gray')
    
with tf.Session() as sess:
    init = tf.initialize_all_variables()
    sess.run(init)
    
    batch_size = 100
    total_batch = int(math.ceil(mnist.train.num_examples/float(batch_size)))
    print("Total batch: %d" % total_batch)    

    training_epochs = 30
    epoch_list = []
    train_error_list = []
    validation_error_list = []
    test_accuracy_list = []
    for epoch in range(training_epochs):
        epoch_list.append(epoch)
        # Train Error Value
        train_error_value = sess.run(error, feed_dict={x: mnist.train.images, y_target: mnist.train.labels})
        train_error_list.append(train_error_value)
        
        validation_error_value = sess.run(error, feed_dict={x: mnist.validation.images, y_target: mnist.validation.labels})
        validation_error_list.append(validation_error_value)
        
        test_accuracy_value = sess.run(accuracy, feed_dict={x: mnist.test.images, y_target: mnist.test.labels})
        test_accuracy_list.append(test_accuracy_value) 
        print("Epoch: {0:2d}, Train Error: {1:0.5f}, Validation Error: {2:0.5f}, Test Accuracy: {3:0.5f}".format(epoch, train_error_value, validation_error_value, test_accuracy_value))
        
        for i in range(total_batch):
            batch_images, batch_labels = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={x: batch_images, y_target: batch_labels})
    

    # Draw Graph about Error Values & Accuracy Values
    draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list)
    
    # False Prediction Profile
    prediction = sess.run(tf.argmax(u, 1), feed_dict={x:mnist.test.images})
    ground_truth = sess.run(tf.argmax(y_target, 1), feed_dict={y_target:mnist.test.labels})

    print(prediction)
    print(ground_truth)

    diff_index_list = []
    for i in range(mnist.test.num_examples):
        if (prediction[i] != ground_truth[i]):
            diff_index_list.append(i)
            
    print("Number of False Prediction:", len(diff_index_list))
    draw_false_prediction(diff_index_list)
# Out:
# Total batch: 550
# Epoch:  0, Train Error: 2.30271, Validation Error: 2.30257, Test Accuracy: 0.09800
# Epoch:  1, Train Error: 0.45252, Validation Error: 0.43107, Test Accuracy: 0.88990
# Epoch:  2, Train Error: 0.38838, Validation Error: 0.36740, Test Accuracy: 0.90160
# Epoch:  3, Train Error: 0.36010, Validation Error: 0.33991, Test Accuracy: 0.90870
# Epoch:  4, Train Error: 0.34428, Validation Error: 0.32497, Test Accuracy: 0.91140
# Epoch:  5, Train Error: 0.33267, Validation Error: 0.31429, Test Accuracy: 0.91330
# Epoch:  6, Train Error: 0.32444, Validation Error: 0.30598, Test Accuracy: 0.91500
# Epoch:  7, Train Error: 0.31756, Validation Error: 0.30056, Test Accuracy: 0.91590
# Epoch:  8, Train Error: 0.31210, Validation Error: 0.29611, Test Accuracy: 0.91640
# Epoch:  9, Train Error: 0.30756, Validation Error: 0.29211, Test Accuracy: 0.91850
# Epoch: 10, Train Error: 0.30457, Validation Error: 0.29026, Test Accuracy: 0.91820
# Epoch: 11, Train Error: 0.30152, Validation Error: 0.28723, Test Accuracy: 0.92040
# Epoch: 12, Train Error: 0.29822, Validation Error: 0.28454, Test Accuracy: 0.91840
# Epoch: 13, Train Error: 0.29557, Validation Error: 0.28302, Test Accuracy: 0.91900
# Epoch: 14, Train Error: 0.29310, Validation Error: 0.28085, Test Accuracy: 0.92040
# Epoch: 15, Train Error: 0.29096, Validation Error: 0.27943, Test Accuracy: 0.92080
# Epoch: 16, Train Error: 0.29087, Validation Error: 0.28018, Test Accuracy: 0.92010
# Epoch: 17, Train Error: 0.28812, Validation Error: 0.27817, Test Accuracy: 0.92070
# Epoch: 18, Train Error: 0.28581, Validation Error: 0.27545, Test Accuracy: 0.92230
# Epoch: 19, Train Error: 0.28423, Validation Error: 0.27466, Test Accuracy: 0.92140
# Epoch: 20, Train Error: 0.28298, Validation Error: 0.27318, Test Accuracy: 0.92250
# Epoch: 21, Train Error: 0.28170, Validation Error: 0.27273, Test Accuracy: 0.92180
# Epoch: 22, Train Error: 0.28070, Validation Error: 0.27238, Test Accuracy: 0.92280
# Epoch: 23, Train Error: 0.27976, Validation Error: 0.27147, Test Accuracy: 0.92180
# Epoch: 24, Train Error: 0.27861, Validation Error: 0.27019, Test Accuracy: 0.92140
# Epoch: 25, Train Error: 0.27804, Validation Error: 0.27034, Test Accuracy: 0.92210
# Epoch: 26, Train Error: 0.27660, Validation Error: 0.26913, Test Accuracy: 0.92180
# Epoch: 27, Train Error: 0.27562, Validation Error: 0.26927, Test Accuracy: 0.92240
# Epoch: 28, Train Error: 0.27629, Validation Error: 0.26884, Test Accuracy: 0.92260
# Epoch: 29, Train Error: 0.27409, Validation Error: 0.26825, Test Accuracy: 0.92190
# [7 2 1 ..., 4 5 6]
# [7 2 1 ..., 4 5 6]
# ('Number of False Prediction:', 775)
# False Prediction Index: 8, Prediction: 6, Ground Truth: 5
# False Prediction Index: 33, Prediction: 6, Ground Truth: 4
# False Prediction Index: 63, Prediction: 2, Ground Truth: 3
# False Prediction Index: 66, Prediction: 7, Ground Truth: 6
# False Prediction Index: 77, Prediction: 7, Ground Truth: 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import math
import tensorflow as tf

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

batch_size = 100
training_epochs = 100
learning_rate = 0.05

epoch_list = []
train_error_list = []
validation_error_list = []
test_accuracy_list = []
diff_index_list = []

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_hidden_1 = 128 # 1st layer number of features
n_hidden_2 = 128 # 2nd layer number of features
n_classes = 10 # MNIST total classes (0-9 digits)
    
# Data Preparation
x = tf.placeholder(tf.float32, [None, n_input])
y_target = tf.placeholder(tf.float32, [None, n_classes])

# Model Construction
# Store layers weight & bias
weights = {
    'W1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'W2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, n_classes]))
}

biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# 1st Hidden layer with RELU activation
u2 = tf.matmul(x, weights['W1']) + biases['b1']
z2 = tf.nn.relu(u2)

# 2ndHidden layer with RELU activation
u3 = tf.matmul(z2, weights['W2']) + biases['b2']
z3 = tf.nn.relu(u3)

# Output layer with linear activation
u_out = tf.matmul(z3, weights['out']) + biases['out']

# Target Setup
error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=u_out, labels=y_target))
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(error)

# Accuracy   
prediction_and_ground_truth = tf.equal(tf.argmax(u_out, 1), tf.argmax(y_target, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_and_ground_truth, tf.float32))

def draw_error_values_and_accuracy():
    # Draw Error Values and Accuracy
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list[1:], train_error_list[1:], 'r', label='Train')
    plt.plot(epoch_list[1:], validation_error_list[1:], 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list[1:], test_accuracy_list[1:], 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(0.0, 1.0, 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.show()
    
def draw_false_prediction():
    fig = plt.figure(figsize=(20, 5))
    for i in range(5):
        j = diff_index_list[i]
        print("False Prediction Index: %s, Prediction: %s, Ground Truth: %s" % (j, prediction[j], ground_truth[j]))
        img = np.array(mnist.test.images[j])
        img.shape = (28, 28)
        plt.subplot(150 + (i+1))
        plt.imshow(img, cmap='gray')
    
with tf.Session() as sess:
    init = tf.initialize_all_variables()
    sess.run(init)
    
    total_batch = int(math.ceil(mnist.train.num_examples/float(batch_size)))
    print("Total batch: %d" % total_batch)    

    for epoch in range(training_epochs):
        epoch_list.append(epoch)
        # Train Error Value
        train_error_value = sess.run(error, feed_dict={x: mnist.train.images, y_target: mnist.train.labels})
        train_error_list.append(train_error_value)
        
        validation_error_value = sess.run(error, feed_dict={x: mnist.validation.images, y_target: mnist.validation.labels})
        validation_error_list.append(validation_error_value)
        
        test_accuracy_value = sess.run(accuracy, feed_dict={x: mnist.test.images, y_target: mnist.test.labels})
        test_accuracy_list.append(test_accuracy_value) 
        print("Epoch: {0:2d}, Train Error: {1:0.5f}, Validation Error: {2:0.5f}, Test Accuracy: {3:0.5f}".format(epoch, train_error_value, validation_error_value, test_accuracy_value))
        
        for i in range(total_batch):
            batch_images, batch_labels = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={x: batch_images, y_target: batch_labels})
    

    # Draw Graph about Error Values & Accuracy Values
    draw_error_values_and_accuracy()
    
    # False Prediction Profile
    prediction = sess.run(tf.argmax(u_out, 1), feed_dict={x:mnist.test.images})
    ground_truth = sess.run(tf.argmax(y_target, 1), feed_dict={y_target:mnist.test.labels})

    print(prediction)
    print(ground_truth)

    for i in range(mnist.test.num_examples):
        if (prediction[i] != ground_truth[i]):
            diff_index_list.append(i)
            
    print("Number of False Prediction:", len(diff_index_list))
    draw_false_prediction()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Total batch: 550
# Epoch:  0, Train Error: 833.95886, Validation Error: 834.09119, Test Accuracy: 0.07070
# Epoch:  1, Train Error: 1.99984, Validation Error: 2.07650, Test Accuracy: 0.47520
# Epoch:  2, Train Error: 1.26843, Validation Error: 1.26711, Test Accuracy: 0.60960
# Epoch:  3, Train Error: 1.08160, Validation Error: 1.13562, Test Accuracy: 0.67780
# Epoch:  4, Train Error: 1.02253, Validation Error: 1.08177, Test Accuracy: 0.70280
# Epoch:  5, Train Error: 0.86850, Validation Error: 0.91139, Test Accuracy: 0.74130
# Epoch:  6, Train Error: 0.72227, Validation Error: 0.75998, Test Accuracy: 0.78300
# Epoch:  7, Train Error: 0.85792, Validation Error: 0.89472, Test Accuracy: 0.73320
# Epoch:  8, Train Error: 0.66459, Validation Error: 0.69272, Test Accuracy: 0.78370
# Epoch:  9, Train Error: 0.64356, Validation Error: 0.67735, Test Accuracy: 0.80230
# Epoch: 10, Train Error: 0.55909, Validation Error: 0.59601, Test Accuracy: 0.83710
# Epoch: 11, Train Error: 0.57536, Validation Error: 0.60957, Test Accuracy: 0.83120
# Epoch: 12, Train Error: 0.52324, Validation Error: 0.57615, Test Accuracy: 0.84700
# Epoch: 13, Train Error: 0.51295, Validation Error: 0.55932, Test Accuracy: 0.85250
# Epoch: 14, Train Error: 0.48108, Validation Error: 0.52613, Test Accuracy: 0.86040
# Epoch: 15, Train Error: 0.48060, Validation Error: 0.53078, Test Accuracy: 0.86230
# Epoch: 16, Train Error: 0.46037, Validation Error: 0.49340, Test Accuracy: 0.86530
# Epoch: 17, Train Error: 0.44310, Validation Error: 0.48406, Test Accuracy: 0.86650
# Epoch: 18, Train Error: 0.41971, Validation Error: 0.46978, Test Accuracy: 0.87620
# Epoch: 19, Train Error: 0.41093, Validation Error: 0.45700, Test Accuracy: 0.87780
# Epoch: 20, Train Error: 0.41566, Validation Error: 0.45464, Test Accuracy: 0.87650
# Epoch: 21, Train Error: 0.42142, Validation Error: 0.46880, Test Accuracy: 0.87360
# Epoch: 22, Train Error: 0.39027, Validation Error: 0.42928, Test Accuracy: 0.88100
# Epoch: 23, Train Error: 0.39373, Validation Error: 0.44682, Test Accuracy: 0.88320
# Epoch: 24, Train Error: 0.38159, Validation Error: 0.43736, Test Accuracy: 0.88870
# Epoch: 25, Train Error: 0.36918, Validation Error: 0.41967, Test Accuracy: 0.88680
# Epoch: 26, Train Error: 0.36212, Validation Error: 0.41691, Test Accuracy: 0.88850
# Epoch: 27, Train Error: 0.35405, Validation Error: 0.40791, Test Accuracy: 0.89290
# Epoch: 28, Train Error: 0.34237, Validation Error: 0.39763, Test Accuracy: 0.89480
# Epoch: 29, Train Error: 0.36047, Validation Error: 0.41884, Test Accuracy: 0.88740
# Epoch: 30, Train Error: 0.34775, Validation Error: 0.40576, Test Accuracy: 0.89050
# Epoch: 31, Train Error: 0.33043, Validation Error: 0.38828, Test Accuracy: 0.89700
# Epoch: 32, Train Error: 0.32884, Validation Error: 0.38651, Test Accuracy: 0.90050
# Epoch: 33, Train Error: 0.33052, Validation Error: 0.39339, Test Accuracy: 0.89130
# Epoch: 34, Train Error: 0.32360, Validation Error: 0.39533, Test Accuracy: 0.90130
# Epoch: 35, Train Error: 0.31351, Validation Error: 0.37239, Test Accuracy: 0.90140
# Epoch: 36, Train Error: 0.32175, Validation Error: 0.38362, Test Accuracy: 0.89470
# Epoch: 37, Train Error: 0.32394, Validation Error: 0.38289, Test Accuracy: 0.89970
# Epoch: 38, Train Error: 0.30345, Validation Error: 0.36351, Test Accuracy: 0.90030
# Epoch: 39, Train Error: 0.30854, Validation Error: 0.36920, Test Accuracy: 0.90170
# Epoch: 40, Train Error: 0.30772, Validation Error: 0.36611, Test Accuracy: 0.89900
# Epoch: 41, Train Error: 0.29293, Validation Error: 0.36661, Test Accuracy: 0.90730
# Epoch: 42, Train Error: 0.30181, Validation Error: 0.37532, Test Accuracy: 0.90420
# Epoch: 43, Train Error: 0.29262, Validation Error: 0.36837, Test Accuracy: 0.90590
# Epoch: 44, Train Error: 0.28002, Validation Error: 0.35120, Test Accuracy: 0.91140
# Epoch: 45, Train Error: 0.28650, Validation Error: 0.35826, Test Accuracy: 0.90940
# Epoch: 46, Train Error: 0.27340, Validation Error: 0.34351, Test Accuracy: 0.90990
# Epoch: 47, Train Error: 0.27522, Validation Error: 0.34961, Test Accuracy: 0.91080
# Epoch: 48, Train Error: 0.27167, Validation Error: 0.35267, Test Accuracy: 0.91150
# Epoch: 49, Train Error: 0.27227, Validation Error: 0.35116, Test Accuracy: 0.91080
# Epoch: 50, Train Error: 0.27788, Validation Error: 0.35302, Test Accuracy: 0.90850
# Epoch: 51, Train Error: 0.26253, Validation Error: 0.33799, Test Accuracy: 0.91460
# Epoch: 52, Train Error: 0.25958, Validation Error: 0.33279, Test Accuracy: 0.91260
# Epoch: 53, Train Error: 0.25877, Validation Error: 0.34151, Test Accuracy: 0.91510
# Epoch: 54, Train Error: 0.25341, Validation Error: 0.33667, Test Accuracy: 0.91590
# Epoch: 55, Train Error: 0.24848, Validation Error: 0.32835, Test Accuracy: 0.91700
# Epoch: 56, Train Error: 0.24891, Validation Error: 0.32944, Test Accuracy: 0.91590
# Epoch: 57, Train Error: 0.27288, Validation Error: 0.35178, Test Accuracy: 0.90830
# Epoch: 58, Train Error: 0.24887, Validation Error: 0.33110, Test Accuracy: 0.91800
# Epoch: 59, Train Error: 0.24470, Validation Error: 0.33580, Test Accuracy: 0.91750
# Epoch: 60, Train Error: 0.25431, Validation Error: 0.34420, Test Accuracy: 0.91260
# Epoch: 61, Train Error: 0.23791, Validation Error: 0.32652, Test Accuracy: 0.92080
# Epoch: 62, Train Error: 0.28559, Validation Error: 0.37294, Test Accuracy: 0.90500
# Epoch: 63, Train Error: 0.25835, Validation Error: 0.34862, Test Accuracy: 0.91340
# Epoch: 64, Train Error: 0.24658, Validation Error: 0.33392, Test Accuracy: 0.91490
# Epoch: 65, Train Error: 0.23338, Validation Error: 0.32430, Test Accuracy: 0.92060
# Epoch: 66, Train Error: 0.24690, Validation Error: 0.34071, Test Accuracy: 0.91640
# Epoch: 67, Train Error: 0.22474, Validation Error: 0.32333, Test Accuracy: 0.92530
# Epoch: 68, Train Error: 0.22459, Validation Error: 0.31467, Test Accuracy: 0.92250
# Epoch: 69, Train Error: 0.22058, Validation Error: 0.32051, Test Accuracy: 0.92430
# Epoch: 70, Train Error: 0.22075, Validation Error: 0.30923, Test Accuracy: 0.92410
# Epoch: 71, Train Error: 0.22468, Validation Error: 0.32541, Test Accuracy: 0.92390
# Epoch: 72, Train Error: 0.21890, Validation Error: 0.31690, Test Accuracy: 0.92400
# Epoch: 73, Train Error: 0.22166, Validation Error: 0.31976, Test Accuracy: 0.92130
# Epoch: 74, Train Error: 0.22420, Validation Error: 0.31487, Test Accuracy: 0.92160
# Epoch: 75, Train Error: 0.21098, Validation Error: 0.30576, Test Accuracy: 0.92650
# Epoch: 76, Train Error: 0.21265, Validation Error: 0.31055, Test Accuracy: 0.92600
# Epoch: 77, Train Error: 0.20920, Validation Error: 0.30785, Test Accuracy: 0.92660
# Epoch: 78, Train Error: 0.20420, Validation Error: 0.30167, Test Accuracy: 0.92760
# Epoch: 79, Train Error: 0.22844, Validation Error: 0.32675, Test Accuracy: 0.91900
# Epoch: 80, Train Error: 0.20605, Validation Error: 0.30502, Test Accuracy: 0.92850
# Epoch: 81, Train Error: 0.20828, Validation Error: 0.31412, Test Accuracy: 0.92610
# Epoch: 82, Train Error: 0.19930, Validation Error: 0.30514, Test Accuracy: 0.92880
# Epoch: 83, Train Error: 0.21428, Validation Error: 0.32071, Test Accuracy: 0.92530
# Epoch: 84, Train Error: 0.20138, Validation Error: 0.30714, Test Accuracy: 0.92800
# Epoch: 85, Train Error: 0.19452, Validation Error: 0.29913, Test Accuracy: 0.93030
# Epoch: 86, Train Error: 0.21533, Validation Error: 0.31467, Test Accuracy: 0.92100
# Epoch: 87, Train Error: 0.19354, Validation Error: 0.30024, Test Accuracy: 0.93030
# Epoch: 88, Train Error: 0.19196, Validation Error: 0.30088, Test Accuracy: 0.92930
# Epoch: 89, Train Error: 0.19353, Validation Error: 0.30050, Test Accuracy: 0.92960
# Epoch: 90, Train Error: 0.19830, Validation Error: 0.31089, Test Accuracy: 0.92880
# Epoch: 91, Train Error: 0.18851, Validation Error: 0.29632, Test Accuracy: 0.93090
# Epoch: 92, Train Error: 0.19293, Validation Error: 0.29970, Test Accuracy: 0.92780
# Epoch: 93, Train Error: 0.19345, Validation Error: 0.30260, Test Accuracy: 0.92760
# Epoch: 94, Train Error: 0.18973, Validation Error: 0.30031, Test Accuracy: 0.93030
# Epoch: 95, Train Error: 0.18740, Validation Error: 0.30089, Test Accuracy: 0.93020
# Epoch: 96, Train Error: 0.18330, Validation Error: 0.29655, Test Accuracy: 0.93190
# Epoch: 97, Train Error: 0.18748, Validation Error: 0.29946, Test Accuracy: 0.92960
# Epoch: 98, Train Error: 0.21000, Validation Error: 0.32132, Test Accuracy: 0.92150
# Epoch: 99, Train Error: 0.18695, Validation Error: 0.29669, Test Accuracy: 0.93230
# [7 2 1 ..., 4 5 6]
# [7 2 1 ..., 4 5 6]
# ('Number of False Prediction:', 672)
# False Prediction Index: 8, Prediction: 4, Ground Truth: 5
# False Prediction Index: 33, Prediction: 0, Ground Truth: 4
# False Prediction Index: 43, Prediction: 1, Ground Truth: 2
# False Prediction Index: 46, Prediction: 3, Ground Truth: 1
# False Prediction Index: 62, Prediction: 8, Ground Truth: 9
