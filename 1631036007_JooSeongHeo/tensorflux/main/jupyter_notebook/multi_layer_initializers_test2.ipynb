# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/Users/yhhan/git/aiclass/0.Professor/")

import tensorflux.graph as tfg
import tensorflux.Multi_Layer_Network as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff
import math
import numba
import numpy as np
import matplotlib.pyplot as plt
print(numba.__version__)
# %matplotlib inline
# Out:
# 0.35.0

# %%
batch_size = 1000
max_epoch = 10
input_size = 784
hidden_layer1_size = 128
hidden_layer2_size = 128
output_size = 10

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

data = mnist.MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)
#data = mnist.Fashion_MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)

# %%
n_xavier_normal = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Xavier_Normal.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
n_xavier_normal.learning(
    max_epoch=max_epoch, 
    data=data, 
    batch_size=batch_size, 
    print_period=5, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()
# Out:
# Multi Layer Network Model - ID: BQ1T5AY3
# -- Learning Started --
# Epoch   0 Completed - Train Error:6.06643 - Validation Error:6.14365 - Test Accuracy:0.10240 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.07147 - Validation Error:0.10933 - Test Accuracy:0.96460 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.04257 - Validation Error:0.13030 - Test Accuracy:0.96340
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:  5 (Fold:  0 & Epoch:  5) - Train Error:0.07147 - Validation Error:0.10933 - Test Accuracy:0.96460
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.04787 - Validation Error:0.10763 - Test Accuracy:0.96520
# Epoch  10 Completed - Train Error:0.05478 - Validation Error:0.10117 - Test Accuracy:0.96890
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 12 (Fold:  1 & Epoch:  2) - Train Error:0.02677 - Validation Error:0.06188 - Test Accuracy:0.96920
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.01526 - Validation Error:0.03850 - Test Accuracy:0.97320
# Epoch  10 Completed - Train Error:0.00102 - Validation Error:0.02871 - Test Accuracy:0.97820
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 23 (Fold:  2 & Epoch:  3) - Train Error:0.01552 - Validation Error:0.02188 - Test Accuracy:0.97360
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.00633 - Validation Error:0.01138 - Test Accuracy:0.97250
# Epoch  10 Completed - Train Error:0.01004 - Validation Error:0.04007 - Test Accuracy:0.97370
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.00313 - Validation Error:0.00639 - Test Accuracy:0.97720
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.02334 - Validation Error:0.02404 - Test Accuracy:0.97170
# Epoch  10 Completed - Train Error:0.00805 - Validation Error:0.04092 - Test Accuracy:0.97430
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.00313 - Validation Error:0.00639 - Test Accuracy:0.97720
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.00659 - Validation Error:0.03602 - Test Accuracy:0.97460
# Epoch  10 Completed - Train Error:0.00125 - Validation Error:0.02078 - Test Accuracy:0.97530
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.00313 - Validation Error:0.00639 - Test Accuracy:0.97720
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.00059 - Validation Error:0.00528 - Test Accuracy:0.97790
# Epoch  10 Completed - Train Error:0.00097 - Validation Error:0.00758 - Test Accuracy:0.97670
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 63 (Fold:  6 & Epoch:  3) - Train Error:0.00133 - Validation Error:0.00263 - Test Accuracy:0.97740
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.04025 - Validation Error:0.05135 - Test Accuracy:0.97230
# Epoch  10 Completed - Train Error:0.00816 - Validation Error:0.04109 - Test Accuracy:0.97650
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 63 (Fold:  6 & Epoch:  3) - Train Error:0.00133 - Validation Error:0.00263 - Test Accuracy:0.97740
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.00583 - Validation Error:0.01230 - Test Accuracy:0.97580
# Epoch  10 Completed - Train Error:0.01991 - Validation Error:0.03258 - Test Accuracy:0.97600
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 63 (Fold:  6 & Epoch:  3) - Train Error:0.00133 - Validation Error:0.00263 - Test Accuracy:0.97740
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.00981 - Validation Error:0.01925 - Test Accuracy:0.97600
# Epoch  10 Completed - Train Error:0.01268 - Validation Error:0.02389 - Test Accuracy:0.97330
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 63 (Fold:  6 & Epoch:  3) - Train Error:0.00133 - Validation Error:0.00263 - Test Accuracy:0.97740
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.01666 - Validation Error:0.03509 - Test Accuracy:0.97310
# Epoch  10 Completed - Train Error:0.00208 - Validation Error:0.00977 - Test Accuracy:0.97800
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 63 (Fold:  6 & Epoch:  3) - Train Error:0.00133 - Validation Error:0.00263 - Test Accuracy:0.97740
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.00440 - Validation Error:0.00808 - Test Accuracy:0.97680
# Epoch  10 Completed - Train Error:0.00041 - Validation Error:0.01054 - Test Accuracy:0.97780
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.00076 - Validation Error:0.00081 - Test Accuracy:0.97810
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --

# %%
n_xavier_uniform = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Xavier_Uniform.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
n_xavier_uniform.learning(
    max_epoch=max_epoch, 
    data=data, 
    batch_size=batch_size, 
    print_period=5, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()
# Out:
# Multi Layer Network Model - ID: PNZCBDVP
# -- Learning Started --
# Epoch   0 Completed - Train Error:8.19187 - Validation Error:8.26463 - Test Accuracy:0.13500 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.07729 - Validation Error:0.12358 - Test Accuracy:0.96280 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.04316 - Validation Error:0.11419 - Test Accuracy:0.96940 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.04316 - Validation Error:0.11419 - Test Accuracy:0.96940
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.02563 - Validation Error:0.07479 - Test Accuracy:0.96890
# Epoch  10 Completed - Train Error:0.01990 - Validation Error:0.09737 - Test Accuracy:0.96890
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 13 (Fold:  1 & Epoch:  3) - Train Error:0.02761 - Validation Error:0.05980 - Test Accuracy:0.97000
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.00731 - Validation Error:0.02445 - Test Accuracy:0.97400 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.00599 - Validation Error:0.02870 - Test Accuracy:0.97420
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 25 (Fold:  2 & Epoch:  5) - Train Error:0.00731 - Validation Error:0.02445 - Test Accuracy:0.97400
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.00778 - Validation Error:0.01381 - Test Accuracy:0.97230 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.02141 - Validation Error:0.02437 - Test Accuracy:0.97340
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 35 (Fold:  3 & Epoch:  5) - Train Error:0.00778 - Validation Error:0.01381 - Test Accuracy:0.97230
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.02193 - Validation Error:0.05066 - Test Accuracy:0.96930
# Epoch  10 Completed - Train Error:0.00354 - Validation Error:0.03691 - Test Accuracy:0.97480
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 35 (Fold:  3 & Epoch:  5) - Train Error:0.00778 - Validation Error:0.01381 - Test Accuracy:0.97230
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.00240 - Validation Error:0.01300 - Test Accuracy:0.97460
# Epoch  10 Completed - Train Error:0.01698 - Validation Error:0.01608 - Test Accuracy:0.97410
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00211 - Validation Error:0.00627 - Test Accuracy:0.97540
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.01745 - Validation Error:0.03087 - Test Accuracy:0.97010
# Epoch  10 Completed - Train Error:0.00259 - Validation Error:0.03736 - Test Accuracy:0.97500
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00211 - Validation Error:0.00627 - Test Accuracy:0.97540
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.01039 - Validation Error:0.01800 - Test Accuracy:0.97520
# Epoch  10 Completed - Train Error:0.01941 - Validation Error:0.04900 - Test Accuracy:0.97370
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00211 - Validation Error:0.00627 - Test Accuracy:0.97540
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.01213 - Validation Error:0.00993 - Test Accuracy:0.97540
# Epoch  10 Completed - Train Error:0.00031 - Validation Error:0.04911 - Test Accuracy:0.97490
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 83 (Fold:  8 & Epoch:  3) - Train Error:0.00093 - Validation Error:0.00283 - Test Accuracy:0.97660
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.02930 - Validation Error:0.03043 - Test Accuracy:0.97270
# Epoch  10 Completed - Train Error:0.00433 - Validation Error:0.02020 - Test Accuracy:0.97680
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 83 (Fold:  8 & Epoch:  3) - Train Error:0.00093 - Validation Error:0.00283 - Test Accuracy:0.97660
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.01947 - Validation Error:0.00938 - Test Accuracy:0.97690
# Epoch  10 Completed - Train Error:0.01981 - Validation Error:0.02838 - Test Accuracy:0.97630
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 83 (Fold:  8 & Epoch:  3) - Train Error:0.00093 - Validation Error:0.00283 - Test Accuracy:0.97660
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.04306 - Validation Error:0.01648 - Test Accuracy:0.97460
# Epoch  10 Completed - Train Error:0.00194 - Validation Error:0.00985 - Test Accuracy:0.97730
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.00204 - Validation Error:0.00095 - Test Accuracy:0.97610
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --

# %%
n_he_normal = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.He_Normal.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
n_he_normal.learning(
    max_epoch=max_epoch, 
    data=data, 
    batch_size=batch_size, 
    print_period=5, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()
# Out:
# Multi Layer Network Model - ID: Q718J4UA
# -- Learning Started --
# Epoch   0 Completed - Train Error:18.80416 - Validation Error:18.67980 - Test Accuracy:0.08680 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.11752 - Validation Error:0.15582 - Test Accuracy:0.94770 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.07204 - Validation Error:0.12878 - Test Accuracy:0.96070
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:  9 (Fold:  0 & Epoch:  9) - Train Error:0.06665 - Validation Error:0.12874 - Test Accuracy:0.95970
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.04889 - Validation Error:0.10250 - Test Accuracy:0.96040
# Epoch  10 Completed - Train Error:0.03230 - Validation Error:0.13254 - Test Accuracy:0.96330
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 11 (Fold:  1 & Epoch:  1) - Train Error:0.04729 - Validation Error:0.06990 - Test Accuracy:0.96080
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.01827 - Validation Error:0.05174 - Test Accuracy:0.96350 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.01866 - Validation Error:0.06668 - Test Accuracy:0.96390
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 25 (Fold:  2 & Epoch:  5) - Train Error:0.01827 - Validation Error:0.05174 - Test Accuracy:0.96350
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.00659 - Validation Error:0.02261 - Test Accuracy:0.96800
# Epoch  10 Completed - Train Error:0.00334 - Validation Error:0.02337 - Test Accuracy:0.97100
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 33 (Fold:  3 & Epoch:  3) - Train Error:0.00573 - Validation Error:0.01757 - Test Accuracy:0.96730
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.00379 - Validation Error:0.00971 - Test Accuracy:0.97100
# Epoch  10 Completed - Train Error:0.00334 - Validation Error:0.01407 - Test Accuracy:0.97120
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.02178 - Validation Error:0.05335 - Test Accuracy:0.96610
# Epoch  10 Completed - Train Error:0.00913 - Validation Error:0.08654 - Test Accuracy:0.96620
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.02958 - Validation Error:0.03193 - Test Accuracy:0.96770
# Epoch  10 Completed - Train Error:0.00050 - Validation Error:0.02656 - Test Accuracy:0.97250
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.01224 - Validation Error:0.02515 - Test Accuracy:0.97270
# Epoch  10 Completed - Train Error:0.00660 - Validation Error:0.04128 - Test Accuracy:0.96850
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.00459 - Validation Error:0.02119 - Test Accuracy:0.97230
# Epoch  10 Completed - Train Error:0.00405 - Validation Error:0.02082 - Test Accuracy:0.97190
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.00446 - Validation Error:0.01486 - Test Accuracy:0.97440
# Epoch  10 Completed - Train Error:0.02365 - Validation Error:0.04903 - Test Accuracy:0.96760
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.01669 - Validation Error:0.02003 - Test Accuracy:0.97210
# Epoch  10 Completed - Train Error:0.02426 - Validation Error:0.04820 - Test Accuracy:0.97000
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.00277 - Validation Error:0.00659 - Test Accuracy:0.96900
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.00084 - Validation Error:0.00676 - Test Accuracy:0.97390
# Epoch  10 Completed - Train Error:0.01142 - Validation Error:0.01502 - Test Accuracy:0.97570
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.01423 - Validation Error:0.00554 - Test Accuracy:0.97390
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --

# %%
n_he_uniform = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.He_Uniform.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
n_he_uniform.learning(
    max_epoch=max_epoch, 
    data=data, 
    batch_size=batch_size, 
    print_period=5, 
    is_numba=True, 
    verbose=False
)
data.reset_kfold()
# Out:
# Multi Layer Network Model - ID: OC7OKTF2
# -- Learning Started --
# Epoch   0 Completed - Train Error:23.85012 - Validation Error:24.17943 - Test Accuracy:0.05900 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.09697 - Validation Error:0.18978 - Test Accuracy:0.94740 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.04293 - Validation Error:0.15553 - Test Accuracy:0.96090 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.04293 - Validation Error:0.15553 - Test Accuracy:0.96090
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.05979 - Validation Error:0.09944 - Test Accuracy:0.95990
# Epoch  10 Completed - Train Error:0.02437 - Validation Error:0.10018 - Test Accuracy:0.96500
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 11 (Fold:  1 & Epoch:  1) - Train Error:0.03214 - Validation Error:0.05762 - Test Accuracy:0.96160
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.00835 - Validation Error:0.03539 - Test Accuracy:0.96800
# Epoch  10 Completed - Train Error:0.02691 - Validation Error:0.07497 - Test Accuracy:0.96580
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 21 (Fold:  2 & Epoch:  1) - Train Error:0.01759 - Validation Error:0.02649 - Test Accuracy:0.96430
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.01045 - Validation Error:0.01798 - Test Accuracy:0.96800
# Epoch  10 Completed - Train Error:0.00322 - Validation Error:0.01200 - Test Accuracy:0.96990 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 40 (Fold:  3 & Epoch: 10) - Train Error:0.00322 - Validation Error:0.01200 - Test Accuracy:0.96990
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.00043 - Validation Error:0.00113 - Test Accuracy:0.97280
# Epoch  10 Completed - Train Error:0.00010 - Validation Error:0.00092 - Test Accuracy:0.97430 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 50 (Fold:  4 & Epoch: 10) - Train Error:0.00010 - Validation Error:0.00092 - Test Accuracy:0.97430
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.08282 - Validation Error:0.10601 - Test Accuracy:0.96140
# Epoch  10 Completed - Train Error:0.00619 - Validation Error:0.07447 - Test Accuracy:0.97070
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.00436 - Validation Error:0.01526 - Test Accuracy:0.97170
# Epoch  10 Completed - Train Error:0.00088 - Validation Error:0.01178 - Test Accuracy:0.97500
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.00030 - Validation Error:0.00688 - Test Accuracy:0.97610
# Epoch  10 Completed - Train Error:0.00006 - Validation Error:0.00251 - Test Accuracy:0.97750
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.11349 - Validation Error:0.11969 - Test Accuracy:0.95980
# Epoch  10 Completed - Train Error:0.01721 - Validation Error:0.04757 - Test Accuracy:0.97170
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.00044 - Validation Error:0.01145 - Test Accuracy:0.97580
# Epoch  10 Completed - Train Error:0.00028 - Validation Error:0.01119 - Test Accuracy:0.97580
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.00011 - Validation Error:0.00660 - Test Accuracy:0.97390
# Epoch  10 Completed - Train Error:0.01659 - Validation Error:0.04185 - Test Accuracy:0.97150
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.01538 - Validation Error:0.02166 - Test Accuracy:0.97440
# Epoch  10 Completed - Train Error:0.00035 - Validation Error:0.01063 - Test Accuracy:0.97600
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00162 - Validation Error:0.00057 - Test Accuracy:0.97280
#
# Load Params from Fold   5 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --

# %%
neural_networks = {
    "xavier_normal": n_xavier_normal, 
    "xavier_uniform": n_xavier_uniform,     
    "he_normal": n_he_normal,         
    "he_uniform": n_he_uniform
}

# %%
for key, neural_network in neural_networks.items():
    print("{:10s} - Epoch:{:3d}, Min Train Error:{:7.5f}, Min Validation Error:{:7.5f}, Test Accuracy:{:7.5f}".format(
        key, 
        neural_network.min_validation_error_epoch,
        neural_network.min_train_error,
        neural_network.min_validation_error,
        neural_network.test_accuracy_at_min_validation_error_epoch
    ))

print()
    
for key, neural_network in neural_networks.items():    
    print("{:10s} - Mean of Min Va. Error For All Folds:{:7.5f}".format(
        key,         
        neural_network.mean_min_validation_error_for_all_folds
    ))
# Out:
# xavier_normal - Epoch:111, Min Train Error:0.00076, Min Validation Error:0.00081, Test Accuracy:0.97810
# xavier_uniform - Epoch:111, Min Train Error:0.00204, Min Validation Error:0.00095, Test Accuracy:0.97610
# he_normal  - Epoch:111, Min Train Error:0.01423, Min Validation Error:0.00554, Test Accuracy:0.97390
# he_uniform - Epoch: 51, Min Train Error:0.00162, Min Validation Error:0.00057, Test Accuracy:0.97280
#
# xavier_normal - Mean of Min Va. Error For All Folds:0.01885
# xavier_uniform - Mean of Min Va. Error For All Folds:0.02119
# he_normal  - Mean of Min Va. Error For All Folds:0.02663
# he_uniform - Mean of Min Va. Error For All Folds:0.02138

# %%
markers = {
    "xavier_normal": "+", 
    "xavier_uniform": "d",     
    "he_normal": "*",         
    "he_uniform": "o"
}

epoch_list = np.arange(len(neural_networks["xavier_normal"].train_error_list))

f, axarr = plt.subplots(2, 2, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0, 0].plot(epoch_list, neural_network.train_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 0].set_ylabel('Train Error')
axarr[0, 0].set_xlabel('Epochs')
axarr[0, 0].grid(True)
axarr[0, 0].set_title('Train Error')
axarr[0, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[0, 1].plot(epoch_list, neural_network.validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 1].set_ylabel('Validation Error')
axarr[0, 1].set_xlabel('Epochs')
axarr[0, 1].grid(True)
axarr[0, 1].set_title('Validation Error')
axarr[0, 1].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 0].plot(epoch_list, neural_network.train_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 0].set_ylabel('Train Error')
axarr[1, 0].set_xlabel('Epochs')
axarr[1, 0].grid(True)
axarr[1, 0].set_ylim(0, 0.15)
axarr[1, 0].set_title('Train Error (0.00 ~ 0.15)')
axarr[1, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 1].plot(epoch_list, neural_network.validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 1].set_ylabel('Validation Error')
axarr[1, 1].set_xlabel('Epochs')
axarr[1, 1].grid(True)
axarr[1, 1].set_ylim(0, 0.15)
axarr[1, 1].set_title('Validation Error (0.00 ~ 0.15)')
axarr[1, 1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)

plt.show()

# %%
f, axarr = plt.subplots(2, 1, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0].plot(epoch_list, neural_network.test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[0].set_ylabel('Test Accuracy')
axarr[0].set_xlabel('Epochs')
axarr[0].grid(True)
axarr[0].set_title('Test Accuracy')
axarr[0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1].plot(epoch_list, neural_network.test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[1].set_ylabel('Test Accuracy')
axarr[1].set_xlabel('Epochs')
axarr[1].grid(True)
axarr[1].set_ylim(0.95, 0.99)
axarr[1].set_title('Test Accuracy (0.95 ~ 0.99)')
axarr[1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)
plt.show()

# %%
neural_networks["xavier_normal"].draw_param_description(figsize=(20, 10))

# %%
neural_networks["xavier_normal"].draw_output_description(figsize=(20, 10))
