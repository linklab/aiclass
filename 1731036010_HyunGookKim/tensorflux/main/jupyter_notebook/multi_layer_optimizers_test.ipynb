# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/Users/yhhan/git/aiclass/0.Professor/")

import tensorflux.graph as tfg
import tensorflux.deep_learning_networks as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff
import math
import numba
import numpy as np
import matplotlib.pyplot as plt
print(numba.__version__)
# %matplotlib inline
# Out:
# 0.35.0

# %%
input_size = 784
hidden_layer1_size = 128
hidden_layer2_size = 128
output_size = 10

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

n_sgd = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.SGD.value,
    learning_rate=0.001
)

n_momentum = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Momentum.value,
    learning_rate=0.001
)

n_adagrad = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.AdaGrad.value,
    learning_rate=0.001
)

n_adam = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)

neural_networks = {"SGD": n_sgd, "Momentum": n_momentum, "AdaGrad": n_adagrad, "Adam": n_adam}
# Out:
# Multi Layer Network Model - ID: HN0NEOT3
# Multi Layer Network Model - ID: JY1R8XR3
# Multi Layer Network Model - ID: R1RDK60S
# Multi Layer Network Model - ID: 7EBXRP4E

# %%
data = mnist.MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)
#data = mnist.Fashion_MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)

# %%
batch_size = 1000
max_epoch = 10

for key, neural_network in neural_networks.items():
    print("***" + key + "***")
    neural_network.learning(
        max_epoch=max_epoch, 
        data=data, 
        batch_size=batch_size, 
        print_period=5, 
        is_numba=True, 
        verbose=False
    )
    data.reset_kfold()
# Out:
# ***SGD***
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.30475 - Validation Error:2.30471 - Test Accuracy:0.10470 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.49062 - Validation Error:0.47020 - Test Accuracy:0.87100 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.33500 - Validation Error:0.34029 - Test Accuracy:0.90300 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.33500 - Validation Error:0.34029 - Test Accuracy:0.90300
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.31714 - Validation Error:0.31797 - Test Accuracy:0.91700 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.26334 - Validation Error:0.29112 - Test Accuracy:0.92550 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  1 & Epoch: 10) - Train Error:0.26334 - Validation Error:0.29112 - Test Accuracy:0.92550
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.24604 - Validation Error:0.28164 - Test Accuracy:0.93170 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.27190 - Validation Error:0.26368 - Test Accuracy:0.93570 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 30 (Fold:  2 & Epoch: 10) - Train Error:0.27190 - Validation Error:0.26368 - Test Accuracy:0.93570
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.21615 - Validation Error:0.21398 - Test Accuracy:0.93860 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.21352 - Validation Error:0.20177 - Test Accuracy:0.94200 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 40 (Fold:  3 & Epoch: 10) - Train Error:0.21352 - Validation Error:0.20177 - Test Accuracy:0.94200
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.19152 - Validation Error:0.20169 - Test Accuracy:0.94400 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.17792 - Validation Error:0.19341 - Test Accuracy:0.94640 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 50 (Fold:  4 & Epoch: 10) - Train Error:0.17792 - Validation Error:0.19341 - Test Accuracy:0.94640
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.13401 - Validation Error:0.17685 - Test Accuracy:0.94870 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.17581 - Validation Error:0.17050 - Test Accuracy:0.95100 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 60 (Fold:  5 & Epoch: 10) - Train Error:0.17581 - Validation Error:0.17050 - Test Accuracy:0.95100
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.12457 - Validation Error:0.16434 - Test Accuracy:0.95290 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.17933 - Validation Error:0.15910 - Test Accuracy:0.95420 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 70 (Fold:  6 & Epoch: 10) - Train Error:0.17933 - Validation Error:0.15910 - Test Accuracy:0.95420
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.14024 - Validation Error:0.14541 - Test Accuracy:0.95550 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.13603 - Validation Error:0.14177 - Test Accuracy:0.95750 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 80 (Fold:  7 & Epoch: 10) - Train Error:0.13603 - Validation Error:0.14177 - Test Accuracy:0.95750
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.14091 - Validation Error:0.13046 - Test Accuracy:0.95920 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.09968 - Validation Error:0.12789 - Test Accuracy:0.96060 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 90 (Fold:  8 & Epoch: 10) - Train Error:0.09968 - Validation Error:0.12789 - Test Accuracy:0.96060
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.09230 - Validation Error:0.14105 - Test Accuracy:0.96170
# Epoch  10 Completed - Train Error:0.11106 - Validation Error:0.13948 - Test Accuracy:0.96320
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 90 (Fold:  8 & Epoch: 10) - Train Error:0.09968 - Validation Error:0.12789 - Test Accuracy:0.96060
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.11258 - Validation Error:0.11605 - Test Accuracy:0.96350 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.10606 - Validation Error:0.11464 - Test Accuracy:0.96420 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:110 (Fold: 10 & Epoch: 10) - Train Error:0.10606 - Validation Error:0.11464 - Test Accuracy:0.96420
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.09441 - Validation Error:0.08060 - Test Accuracy:0.96490
# Epoch  10 Completed - Train Error:0.08552 - Validation Error:0.08024 - Test Accuracy:0.96590
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.10165 - Validation Error:0.08014 - Test Accuracy:0.96430
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***Momentum***
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.31117 - Validation Error:2.31345 - Test Accuracy:0.11700 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.20552 - Validation Error:0.19029 - Test Accuracy:0.94240 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.15801 - Validation Error:0.12665 - Test Accuracy:0.96000 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.15801 - Validation Error:0.12665 - Test Accuracy:0.96000
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.06855 - Validation Error:0.11117 - Test Accuracy:0.96710 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.07817 - Validation Error:0.10198 - Test Accuracy:0.97090 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  1 & Epoch: 10) - Train Error:0.07817 - Validation Error:0.10198 - Test Accuracy:0.97090
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.07039 - Validation Error:0.06159 - Test Accuracy:0.97370
# Epoch  10 Completed - Train Error:0.04979 - Validation Error:0.06320 - Test Accuracy:0.97470
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 21 (Fold:  2 & Epoch:  1) - Train Error:0.05867 - Validation Error:0.05759 - Test Accuracy:0.97130
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.03675 - Validation Error:0.04842 - Test Accuracy:0.97600
# Epoch  10 Completed - Train Error:0.01389 - Validation Error:0.04281 - Test Accuracy:0.97690
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.02784 - Validation Error:0.04265 - Test Accuracy:0.97570
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.01940 - Validation Error:0.02537 - Test Accuracy:0.97840
# Epoch  10 Completed - Train Error:0.02542 - Validation Error:0.02670 - Test Accuracy:0.97750
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.03642 - Validation Error:0.02229 - Test Accuracy:0.97790
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.01518 - Validation Error:0.01993 - Test Accuracy:0.97770
# Epoch  10 Completed - Train Error:0.01531 - Validation Error:0.02645 - Test Accuracy:0.97730
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.00787 - Validation Error:0.01516 - Test Accuracy:0.97760
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.00904 - Validation Error:0.01169 - Test Accuracy:0.97790 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.00676 - Validation Error:0.01418 - Test Accuracy:0.97840
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 67 (Fold:  6 & Epoch:  7) - Train Error:0.00772 - Validation Error:0.01096 - Test Accuracy:0.97890
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.01651 - Validation Error:0.01445 - Test Accuracy:0.97700
# Epoch  10 Completed - Train Error:0.00701 - Validation Error:0.01169 - Test Accuracy:0.97820
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 71 (Fold:  7 & Epoch:  1) - Train Error:0.00864 - Validation Error:0.01080 - Test Accuracy:0.97760
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.01074 - Validation Error:0.00900 - Test Accuracy:0.97870
# Epoch  10 Completed - Train Error:0.00864 - Validation Error:0.01049 - Test Accuracy:0.97820
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.00559 - Validation Error:0.00467 - Test Accuracy:0.97900
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.00211 - Validation Error:0.00340 - Test Accuracy:0.97930 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.00177 - Validation Error:0.00349 - Test Accuracy:0.97920
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 97 (Fold:  9 & Epoch:  7) - Train Error:0.00152 - Validation Error:0.00325 - Test Accuracy:0.97880
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.00178 - Validation Error:0.00183 - Test Accuracy:0.97890
# Epoch  10 Completed - Train Error:0.00162 - Validation Error:0.00213 - Test Accuracy:0.97910
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:102 (Fold: 10 & Epoch:  2) - Train Error:0.00198 - Validation Error:0.00171 - Test Accuracy:0.97870
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.00127 - Validation Error:0.00140 - Test Accuracy:0.97890
# Epoch  10 Completed - Train Error:0.00119 - Validation Error:0.00162 - Test Accuracy:0.97930
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.00207 - Validation Error:0.00117 - Test Accuracy:0.97900
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***AdaGrad***
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.32101 - Validation Error:2.31569 - Test Accuracy:0.11160 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.21447 - Validation Error:0.18804 - Test Accuracy:0.94200 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.17112 - Validation Error:0.15068 - Test Accuracy:0.95460 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.17112 - Validation Error:0.15068 - Test Accuracy:0.95460
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.10883 - Validation Error:0.14151 - Test Accuracy:0.95980 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.09196 - Validation Error:0.13021 - Test Accuracy:0.96380 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  1 & Epoch: 10) - Train Error:0.09196 - Validation Error:0.13021 - Test Accuracy:0.96380
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.08722 - Validation Error:0.10042 - Test Accuracy:0.96630 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.08316 - Validation Error:0.09574 - Test Accuracy:0.96790 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 30 (Fold:  2 & Epoch: 10) - Train Error:0.08316 - Validation Error:0.09574 - Test Accuracy:0.96790
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.11154 - Validation Error:0.07960 - Test Accuracy:0.96920 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.06469 - Validation Error:0.07789 - Test Accuracy:0.96960 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 40 (Fold:  3 & Epoch: 10) - Train Error:0.06469 - Validation Error:0.07789 - Test Accuracy:0.96960
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.08930 - Validation Error:0.07552 - Test Accuracy:0.97020
# Epoch  10 Completed - Train Error:0.05591 - Validation Error:0.07533 - Test Accuracy:0.97100
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.06831 - Validation Error:0.07477 - Test Accuracy:0.96970
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.06075 - Validation Error:0.06600 - Test Accuracy:0.97180
# Epoch  10 Completed - Train Error:0.05758 - Validation Error:0.06671 - Test Accuracy:0.97300
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.05985 - Validation Error:0.06447 - Test Accuracy:0.97110
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.05419 - Validation Error:0.05499 - Test Accuracy:0.97370
# Epoch  10 Completed - Train Error:0.05559 - Validation Error:0.05546 - Test Accuracy:0.97400
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 61 (Fold:  6 & Epoch:  1) - Train Error:0.06681 - Validation Error:0.05395 - Test Accuracy:0.97310
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.04096 - Validation Error:0.05648 - Test Accuracy:0.97450
# Epoch  10 Completed - Train Error:0.04084 - Validation Error:0.05762 - Test Accuracy:0.97480
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 61 (Fold:  6 & Epoch:  1) - Train Error:0.06681 - Validation Error:0.05395 - Test Accuracy:0.97310
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.04977 - Validation Error:0.04629 - Test Accuracy:0.97470
# Epoch  10 Completed - Train Error:0.03928 - Validation Error:0.04736 - Test Accuracy:0.97520
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.04998 - Validation Error:0.04475 - Test Accuracy:0.97460
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.03810 - Validation Error:0.04625 - Test Accuracy:0.97530
# Epoch  10 Completed - Train Error:0.03294 - Validation Error:0.04764 - Test Accuracy:0.97500
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 91 (Fold:  9 & Epoch:  1) - Train Error:0.04866 - Validation Error:0.04434 - Test Accuracy:0.97500
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.03744 - Validation Error:0.03348 - Test Accuracy:0.97540
# Epoch  10 Completed - Train Error:0.05504 - Validation Error:0.03438 - Test Accuracy:0.97560
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:101 (Fold: 10 & Epoch:  1) - Train Error:0.03586 - Validation Error:0.03208 - Test Accuracy:0.97550
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.02090 - Validation Error:0.02697 - Test Accuracy:0.97630
# Epoch  10 Completed - Train Error:0.01809 - Validation Error:0.02804 - Test Accuracy:0.97650
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.03012 - Validation Error:0.02545 - Test Accuracy:0.97620
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***Adam***
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.31966 - Validation Error:2.32062 - Test Accuracy:0.11580 <== Minimal Val. Error
# Fold:  0
# Epoch   5 Completed - Train Error:0.07390 - Validation Error:0.10629 - Test Accuracy:0.96490
# Epoch  10 Completed - Train Error:0.04137 - Validation Error:0.09971 - Test Accuracy:0.96940
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:  8 (Fold:  0 & Epoch:  8) - Train Error:0.04142 - Validation Error:0.08893 - Test Accuracy:0.97150
#
# Fold:  1
# Epoch   5 Completed - Train Error:0.04193 - Validation Error:0.07482 - Test Accuracy:0.97100
# Epoch  10 Completed - Train Error:0.02545 - Validation Error:0.07069 - Test Accuracy:0.97300
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 12 (Fold:  1 & Epoch:  2) - Train Error:0.01104 - Validation Error:0.04209 - Test Accuracy:0.97760
#
# Fold:  2
# Epoch   5 Completed - Train Error:0.02954 - Validation Error:0.04139 - Test Accuracy:0.97390
# Epoch  10 Completed - Train Error:0.01228 - Validation Error:0.02717 - Test Accuracy:0.97900 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 30 (Fold:  2 & Epoch: 10) - Train Error:0.01228 - Validation Error:0.02717 - Test Accuracy:0.97900
#
# Fold:  3
# Epoch   5 Completed - Train Error:0.01464 - Validation Error:0.01677 - Test Accuracy:0.97700
# Epoch  10 Completed - Train Error:0.00344 - Validation Error:0.02365 - Test Accuracy:0.97780
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 34 (Fold:  3 & Epoch:  4) - Train Error:0.00747 - Validation Error:0.01336 - Test Accuracy:0.97770
#
# Fold:  4
# Epoch   5 Completed - Train Error:0.00151 - Validation Error:0.02273 - Test Accuracy:0.97860
# Epoch  10 Completed - Train Error:0.00206 - Validation Error:0.02440 - Test Accuracy:0.97650
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 46 (Fold:  4 & Epoch:  6) - Train Error:0.00910 - Validation Error:0.00897 - Test Accuracy:0.97950
#
# Fold:  5
# Epoch   5 Completed - Train Error:0.01591 - Validation Error:0.03582 - Test Accuracy:0.97610
# Epoch  10 Completed - Train Error:0.00247 - Validation Error:0.02631 - Test Accuracy:0.97840
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 46 (Fold:  4 & Epoch:  6) - Train Error:0.00910 - Validation Error:0.00897 - Test Accuracy:0.97950
#
# Fold:  6
# Epoch   5 Completed - Train Error:0.00095 - Validation Error:0.01352 - Test Accuracy:0.98060
# Epoch  10 Completed - Train Error:0.01070 - Validation Error:0.02113 - Test Accuracy:0.97900
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 61 (Fold:  6 & Epoch:  1) - Train Error:0.01976 - Validation Error:0.00802 - Test Accuracy:0.97760
#
# Fold:  7
# Epoch   5 Completed - Train Error:0.00703 - Validation Error:0.02162 - Test Accuracy:0.97720
# Epoch  10 Completed - Train Error:0.00137 - Validation Error:0.02972 - Test Accuracy:0.97710
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 73 (Fold:  7 & Epoch:  3) - Train Error:0.00359 - Validation Error:0.00517 - Test Accuracy:0.98110
#
# Fold:  8
# Epoch   5 Completed - Train Error:0.00488 - Validation Error:0.00879 - Test Accuracy:0.97910
# Epoch  10 Completed - Train Error:0.09821 - Validation Error:0.03638 - Test Accuracy:0.97450
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.00052 - Validation Error:0.00497 - Test Accuracy:0.97980
#
# Fold:  9
# Epoch   5 Completed - Train Error:0.01628 - Validation Error:0.02319 - Test Accuracy:0.98000
# Epoch  10 Completed - Train Error:0.00625 - Validation Error:0.01757 - Test Accuracy:0.97680
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.00052 - Validation Error:0.00497 - Test Accuracy:0.97980
#
# Fold:  10
# Epoch   5 Completed - Train Error:0.01485 - Validation Error:0.01146 - Test Accuracy:0.97910
# Epoch  10 Completed - Train Error:0.00152 - Validation Error:0.00920 - Test Accuracy:0.98080
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.00052 - Validation Error:0.00497 - Test Accuracy:0.97980
#
# Fold:  11
# Epoch   5 Completed - Train Error:0.00277 - Validation Error:0.00640 - Test Accuracy:0.98060
# Epoch  10 Completed - Train Error:0.00005 - Validation Error:0.00175 - Test Accuracy:0.98180
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:111 (Fold: 11 & Epoch:  1) - Train Error:0.00050 - Validation Error:0.00066 - Test Accuracy:0.98120
#
# Load Params from Fold  11 & Epoch   1
# Params are set to the best model!!!
# -- Learning Finished --

# %%
for key, neural_network in neural_networks.items():
    print("{:10s} - Epoch:{:3d}, Min Train Error:{:7.5f}, Min Validation Error:{:7.5f}, Test Accuracy:{:7.5f}".format(
        key, 
        neural_network.min_validation_error_epoch,
        neural_network.min_train_error,
        neural_network.min_validation_error,
        neural_network.test_accuracy_at_min_validation_error_epoch
    ))

print()
    
for key, neural_network in neural_networks.items():    
    print("{:10s} - Mean of Min Va. Error For All Folds:{:7.5f}".format(
        key,         
        neural_network.mean_min_validation_error_for_all_folds
    ))
# Out:
# SGD        - Epoch:111, Min Train Error:0.10165, Min Validation Error:0.08014, Test Accuracy:0.96430
# Momentum   - Epoch:111, Min Train Error:0.00207, Min Validation Error:0.00117, Test Accuracy:0.97900
# AdaGrad    - Epoch:111, Min Train Error:0.03012, Min Validation Error:0.02545, Test Accuracy:0.97620
# Adam       - Epoch:111, Min Train Error:0.00050, Min Validation Error:0.00066, Test Accuracy:0.98120
#
# SGD        - Mean of Min Va. Error For All Folds:0.18435
# Momentum   - Mean of Min Va. Error For All Folds:0.03324
# AdaGrad    - Mean of Min Va. Error For All Folds:0.07069
# Adam       - Mean of Min Va. Error For All Folds:0.01819

# %%
#markers = {"SGD": "h", "Momentum": "x", "Nesterov": "s", "AdaGrad": "o", "Adam": "1"}
markers = {"SGD": "h", "Momentum": "x", "AdaGrad": "o", "Adam": "1"}

epoch_list = np.arange(len(neural_networks["SGD"].train_error_list))

f, axarr = plt.subplots(2, 2, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0, 0].plot(epoch_list, neural_network.train_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 0].set_ylabel('Train Error')
axarr[0, 0].set_xlabel('Epochs')
axarr[0, 0].grid(True)
axarr[0, 0].set_title('Train Error')
axarr[0, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[0, 1].plot(epoch_list, neural_network.validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 1].set_ylabel('Validation Error')
axarr[0, 1].set_xlabel('Epochs')
axarr[0, 1].grid(True)
axarr[0, 1].set_title('Validation Error')
axarr[0, 1].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 0].plot(epoch_list, neural_network.train_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 0].set_ylabel('Train Error')
axarr[1, 0].set_xlabel('Epochs')
axarr[1, 0].grid(True)
axarr[1, 0].set_ylim(0, 0.3)
axarr[1, 0].set_title('Train Error (0.00 ~ 0.30)')
axarr[1, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 1].plot(epoch_list, neural_network.validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 1].set_ylabel('Validation Error')
axarr[1, 1].set_xlabel('Epochs')
axarr[1, 1].grid(True)
axarr[1, 1].set_ylim(0, 0.3)
axarr[1, 1].set_title('Validation Error (0.00 ~ 0.30)')
axarr[1, 1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)

plt.show()

# %%
f, axarr = plt.subplots(2, 1, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0].plot(epoch_list, neural_networks[key].test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[0].set_ylabel('Test Accuracy')
axarr[0].set_xlabel('Epochs')
axarr[0].grid(True)
axarr[0].set_title('Test Accuracy')
axarr[0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1].plot(epoch_list, neural_networks[key].test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[1].set_ylabel('Test Accuracy')
axarr[1].set_xlabel('Epochs')
axarr[1].grid(True)
axarr[1].set_ylim(0.92, 0.99)
axarr[1].set_title('Test Accuracy (0.92 ~ 0.99)')
axarr[1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)
plt.show()

# %%
neural_networks["Adam"].draw_param_description(figsize=(20, 10))

# %%
neural_networks["Adam"].draw_output_description(figsize=(20, 10))
