# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/home/ubuntu/git/aiclass/1731036010_HyunGookKim/")

import tensorflux.graph as tfg
import tensorflux.deep_learning_networks as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff
import math
import numba
import numpy as np
import matplotlib.pyplot as plt
print(numba.__version__)
# %matplotlib inline
# Out:
# 0.35.0

# %%
input_size = 784
hidden_layer1_size = 128
hidden_layer2_size = 128
output_size = 10
model_params_dir = "/home/ubuntu/temp3"

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

n_sgd = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    init_mean=0.0,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.SGD.value,
    learning_rate=0.01,
    model_params_dir=model_params_dir
)

n_momentum = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    init_mean=0.0,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Momentum.value,
    learning_rate=0.01,
    model_params_dir=model_params_dir
)

n_nag = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    init_mean=0.0,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.NAG.value,
    learning_rate=0.01,
    model_params_dir=model_params_dir
)

n_adagrad = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    init_mean=0.0,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.AdaGrad.value,
    learning_rate=0.01,
    model_params_dir=model_params_dir
)

n_adam = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer1_size, hidden_layer2_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    init_mean=0.0,
    init_sd=0.01,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.01,
    model_params_dir=model_params_dir
)
# Out:
# Multi Layer Network Model - ID: DG6M9ZA2
# Multi Layer Network Model - ID: K53QJ9X2
# Multi Layer Network Model - ID: EHFPYJIO
# Multi Layer Network Model - ID: 0DU5QA0X
# Multi Layer Network Model - ID: I2PPNWSU

# %%
data = mnist.MNIST_Data()
#data = mnist.Fashion_MNIST_Data()

# %%
batch_size = 1000
max_epoch = 3

neural_networks = {"SGD": n_sgd, "Momentum": n_momentum, "Nesterov": n_nag, "AdaGrad": n_adagrad, "Adam": n_adam}
#neural_networks = {"AdaGrad": n_adagrad, "Adam": n_adam}

for key, neural_network in neural_networks.items():
    print("***" + key + "***")
    neural_network.learning(
        max_epoch=max_epoch, 
        data=data, 
        batch_size=batch_size, 
        print_period=1, 
        is_numba=False, 
        verbose=False
    )
# Out:
# ***SGD***
# -- Learning Started --
# Epoch   0 Completed - Train Error: 2.328839 - Validation Error: 2.326284 - Test Accuracy: 0.086800
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   1 Completed - Train Error: 0.487421 - Validation Error: 0.426158 - Test Accuracy: 0.867700
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   2 Completed - Train Error: 0.308936 - Validation Error: 0.271135 - Test Accuracy: 0.918300
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   3 Completed - Train Error: 0.246933 - Validation Error: 0.219526 - Test Accuracy: 0.934400
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Epoch   3 Completed - Train Error: 0.246933 - Validation Error: 0.219526 - Test Accuracy: 0.934400
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***Momentum***
# -- Learning Started --
# Epoch   0 Completed - Train Error: 2.296645 - Validation Error: 2.292398 - Test Accuracy: 0.106600
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   1 Completed - Train Error: 0.259630 - Validation Error: 0.237040 - Test Accuracy: 0.928700
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   2 Completed - Train Error: 0.162607 - Validation Error: 0.139564 - Test Accuracy: 0.953000
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   3 Completed - Train Error: 0.123453 - Validation Error: 0.126911 - Test Accuracy: 0.958100
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Epoch   3 Completed - Train Error: 0.123453 - Validation Error: 0.126911 - Test Accuracy: 0.958100
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***Nesterov***
# -- Learning Started --
# Epoch   0 Completed - Train Error: 2.321650 - Validation Error: 2.326043 - Test Accuracy: 0.120800
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   1 Completed - Train Error: 0.245207 - Validation Error: 0.227032 - Test Accuracy: 0.932500
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   2 Completed - Train Error: 0.171284 - Validation Error: 0.153731 - Test Accuracy: 0.950900
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   3 Completed - Train Error: 0.125811 - Validation Error: 0.145596 - Test Accuracy: 0.955500
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Epoch   3 Completed - Train Error: 0.125811 - Validation Error: 0.145596 - Test Accuracy: 0.955500
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***AdaGrad***
# -- Learning Started --
# Epoch   0 Completed - Train Error: 2.303353 - Validation Error: 2.298354 - Test Accuracy: 0.119000
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   1 Completed - Train Error: 0.286092 - Validation Error: 0.253926 - Test Accuracy: 0.919200
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   2 Completed - Train Error: 0.176466 - Validation Error: 0.174152 - Test Accuracy: 0.942600
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   3 Completed - Train Error: 0.126178 - Validation Error: 0.141335 - Test Accuracy: 0.954900
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Epoch   3 Completed - Train Error: 0.126178 - Validation Error: 0.141335 - Test Accuracy: 0.954900
# Params are set to the best model!!!
# -- Learning Finished --
#
# ***Adam***
# -- Learning Started --
# Epoch   0 Completed - Train Error: 2.320722 - Validation Error: 2.322147 - Test Accuracy: 0.096900
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   1 Completed - Train Error: 0.475347 - Validation Error: 0.466822 - Test Accuracy: 0.846600
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   2 Completed - Train Error: 0.336870 - Validation Error: 0.309400 - Test Accuracy: 0.899300
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
# Epoch   3 Completed - Train Error: 0.308518 - Validation Error: 0.296093 - Test Accuracy: 0.902500
# W0:(784, 128):802816
# b0:(128,):1024
# W1:(128, 128):131072
# b1:(128,):1024
# W2:(128, 10):10240
# b2:(10,):80
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Epoch   3 Completed - Train Error: 0.308518 - Validation Error: 0.296093 - Test Accuracy: 0.902500
# Params are set to the best model!!!
# -- Learning Finished --

# %%
for key, neural_network in neural_networks.items():
    print("{:10s} - Epoch:{:3d}, Min Train Error: {:7.5f}, Min ValidationError: {:7.5f}, Max Test Accuracy: {:7.5f}".format(
        key, 
        neural_networks[key].min_validation_error_epoch,
        neural_networks[key].min_train_error,
        neural_networks[key].min_validation_error,
        neural_networks[key].max_test_accuracy,
        )
    )
# Out:
# SGD        - Epoch:  3, Min Train Error: 0.24693, Min ValidationError: 0.21953, Max Test Accuracy: 0.93440
# Momentum   - Epoch:  3, Min Train Error: 0.12345, Min ValidationError: 0.12691, Max Test Accuracy: 0.95810
# Nesterov   - Epoch:  3, Min Train Error: 0.12581, Min ValidationError: 0.14560, Max Test Accuracy: 0.95550
# AdaGrad    - Epoch:  3, Min Train Error: 0.12618, Min ValidationError: 0.14134, Max Test Accuracy: 0.95490
# Adam       - Epoch:  3, Min Train Error: 0.30852, Min ValidationError: 0.29609, Max Test Accuracy: 0.90250

# %%
markers = {"SGD": "h", "Momentum": "x", "Nesterov": "s", "AdaGrad": "o", "Adam": "1"}
epoch_list = np.arange(max_epoch + 1)

f, axarr = plt.subplots(2, 2, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0, 0].plot(epoch_list, neural_networks[key].train_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 0].set_ylabel('Train Error')
axarr[0, 0].set_xlabel('Epochs')
axarr[0, 0].grid(True)
axarr[0, 0].set_title('Train Error')
axarr[0, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[0, 1].plot(epoch_list, neural_networks[key].validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[0, 1].set_ylabel('Validation Error')
axarr[0, 1].set_xlabel('Epochs')
axarr[0, 1].grid(True)
axarr[0, 1].set_title('Validation Error')
axarr[0, 1].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 0].plot(epoch_list, neural_networks[key].train_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 0].set_ylabel('Train Error')
axarr[1, 0].set_xlabel('Epochs')
axarr[1, 0].grid(True)
axarr[1, 0].set_ylim(0, 0.3)
axarr[1, 0].set_title('Train Error (0.00 ~ 0.30)')
axarr[1, 0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[1, 1].plot(epoch_list, neural_networks[key].validation_error_list, marker=markers[key], markevery=2, label=key)
axarr[1, 1].set_ylabel('Validation Error')
axarr[1, 1].set_xlabel('Epochs')
axarr[1, 1].grid(True)
axarr[1, 1].set_ylim(0, 0.3)
axarr[1, 1].set_title('Validation Error (0.00 ~ 0.30)')
axarr[1, 1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)

plt.show()

# %%
f, axarr = plt.subplots(2, 1, figsize=(15,10))

for key, neural_network in neural_networks.items():
    axarr[0].plot(epoch_list, neural_networks[key].test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[0].set_ylabel('Test Accuracy')
axarr[0].set_xlabel('Epochs')
axarr[0].grid(True)
axarr[0].set_title('Test Accuracy')
axarr[0].legend(loc='upper left')

for key, neural_network in neural_networks.items():
    axarr[0].plot(epoch_list, neural_networks[key].test_accuracy_list, marker=markers[key], markevery=1, label=key)
axarr[1].set_ylabel('Test Accuracy')
axarr[1].set_xlabel('Epochs')
axarr[1].grid(True)
axarr[1].set_ylim(0.9, 1.0)
axarr[1].set_title('Test Accuracy (0.9 ~ 1.0)')
axarr[1].legend(loc='upper left')

f.subplots_adjust(hspace=0.3)
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
