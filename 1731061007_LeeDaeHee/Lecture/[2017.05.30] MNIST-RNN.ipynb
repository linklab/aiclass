# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
print(tf.__version__)
# Out:
# 1.0.1

# %%
mnist = input_data.read_data_sets("../MNIST_data/", one_hot=True)
# Out:
# Extracting ../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# configuration
#                        output[-1] * W + b -> 10 labels for each image, output[-1]:[? 28], W:[28 10], B:[10]
#                       ^ (O: output 28 vec from 28 vec input)
#                       |
#      +-+  +-+       +--+
#      |1|->|2|-> ... |28| n_steps = 28
#      +-+  +-+       +--+
#       ^    ^    ...  ^
#       |    |         |
# img1:[28] [28]  ... [28]
# img2:[28] [28]  ... [28]
# img3:[28] [28]  ... [28]
# ...
# img128 or img256 (batch_size or test_size 256)
# each n_inputs = n_state_units = 28

# %%
batch_size = 128
n_inputs = 28
n_steps = 28
n_state_units = 56
learning_rate = 0.001
n_classes = 10

x = tf.placeholder(tf.float32, [None, n_steps, n_inputs]) #실제 이미지를 넣음
xt = tf.transpose(x, perm = [1, 0, 2])
xr = tf.reshape(xt, shape = [-1, n_inputs])
xs = tf.split(value=xr, num_or_size_splits=n_steps, axis=0) 

#rnn_cell = tf.contrib.rnn.BasicRNNCell(num_units = n_state_units)
rnn_cell = tf.contrib.rnn.BasicLSTMCell(num_units = n_state_units)
initial_state = rnn_cell.zero_state(batch_size=batch_size, dtype=tf.float32)
print("rnn_cell.output_size:", rnn_cell.output_size)
print("rnn_cell.state_size:", rnn_cell.state_size)
print(initial_state)
print()

outputs, final_state = tf.contrib.rnn.static_rnn(rnn_cell, xs, dtype=tf.float32)
print("Type of outputs: {0}, Type of state: {1}".format(type(outputs), type(final_state)))
print("length of outputs:", len(outputs))
print()

W2 = tf.Variable(tf.random_normal([n_state_units, n_classes]))
B = tf.Variable(tf.random_normal([n_classes]))

pred = tf.matmul(outputs[-1], W2) + B

y = tf.placeholder(tf.float32, [None, n_classes])

error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(error)

correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# rnn_cell.output_size: 56
# rnn_cell.state_size: LSTMStateTuple(c=56, h=56)
# LSTMStateTuple(c=<tf.Tensor 'zeros:0' shape=(128, 56) dtype=float32>, h=<tf.Tensor 'zeros_1:0' shape=(128, 56) dtype=float32>)
#
# Type of outputs: <class 'list'>, Type of state: <class 'tensorflow.contrib.rnn.python.ops.core_rnn_cell_impl.LSTMStateTuple'>
# length of outputs: 28

# %%
def printLossAccuracyForTestData(epoch, sess, test_accuracy_list):
    test_data = mnist.test.images.reshape((-1, n_steps, n_inputs))
    test_labels = mnist.test.labels
    accuracy_value, error_value = sess.run((accuracy, error), feed_dict={x: test_data, y: test_labels})
    test_accuracy_list.append(accuracy_value)
    print("epoch: {0}, test_error_value: {1}, test accuracy: {2}".format(epoch, error_value, accuracy_value))

def drawErrorValues(epoch_list, train_error_value_list, validation_error_value_list, test_accuracy_list):
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list, train_error_value_list, 'r', label='Train')
    plt.plot(epoch_list, validation_error_value_list, 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list, test_accuracy_list, 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(min(test_accuracy_list), max(test_accuracy_list), 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')            
    plt.show()
    
def drawFalsePrediction(epoch, sess, numPrintImages):
    test_data = mnist.test.images.reshape((-1, n_steps, n_inputs))
    test_labels = mnist.test.labels
    correct_pred_value = sess.run(correct_pred, feed_dict={x: test_data, y: test_labels})
    ground_truth = sess.run(tf.argmax(y, 1), feed_dict={y: test_labels})
    prediction = sess.run(tf.argmax(pred, 1), feed_dict={x: test_data})

    fig = plt.figure(figsize=(20, 5))
    j = 1
    for i in range(len(correct_pred_value)):
        if (j > numPrintImages):
            break;
        if (not correct_pred_value[i]):
            ground_truth_num = mnist.test.labels[i]
            print("Error Index: {0}, Prediction: {1}, Ground Truth: {2}".format(i, prediction[i], ground_truth[i]))
            img = np.array(mnist.test.images[i])
            img.shape = (28, 28)
            plt.subplot(1, numPrintImages, j)
            plt.imshow(img)
            j += 1

# %%
init = tf.global_variables_initializer()

max_training_epochs = 100
batch_size = 128
n_inputs = 28
n_steps = 28

epoch_list                  = []
train_error_value_list      = []
validation_error_value_list = []
test_error_value_list       = []
test_accuracy_list          = []

with tf.Session() as sess:
    sess.run(init)
    
    print("mnist.train.num_examples", mnist.train.num_examples)
    print("batch_size", batch_size)
    total_batch = int(math.ceil(mnist.train.num_examples / float(batch_size)))
    print("Total batch: {0}".format(total_batch))
    
    for epoch in range(max_training_epochs):
        for i in range(total_batch):
            batch_images, batch_labels = mnist.train.next_batch(batch_size)
            batch_images = batch_images.reshape((batch_size, n_steps, n_inputs))
            sess.run((optimizer, error), feed_dict={x: batch_images, y: batch_labels})
        
        epoch_list.append(epoch)
        
        t_images = mnist.train.images.reshape((mnist.train.num_examples, n_steps, n_inputs))
        t_labels = mnist.train.labels
        t_error_value = sess.run(error, feed_dict={x: t_images, y: t_labels})
        train_error_value_list.append(t_error_value)
        
        v_images = mnist.validation.images.reshape((mnist.validation.num_examples, n_steps, n_inputs))
        v_labels = mnist.validation.labels
        v_error_value = sess.run(error, feed_dict={x: v_images, y: v_labels})
        validation_error_value_list.append(v_error_value)
            
        printLossAccuracyForTestData(epoch, sess, test_accuracy_list)
            
    print("train complete!")
    drawErrorValues(epoch_list, train_error_value_list, validation_error_value_list, test_accuracy_list)
    drawFalsePrediction(epoch, sess, 10)
# Out:
# mnist.train.num_examples 55000
# batch_size 128
# Total batch: 430
# epoch: 0, test_error_value: 0.2597702145576477, test accuracy: 0.9194999933242798
# epoch: 1, test_error_value: 0.1678626537322998, test accuracy: 0.9492999911308289
# epoch: 2, test_error_value: 0.12767978012561798, test accuracy: 0.9591000080108643
# epoch: 3, test_error_value: 0.09512585401535034, test accuracy: 0.9692999720573425
# epoch: 4, test_error_value: 0.08229067176580429, test accuracy: 0.9735999703407288
# epoch: 5, test_error_value: 0.07810985296964645, test accuracy: 0.9746999740600586
# epoch: 6, test_error_value: 0.07273780554533005, test accuracy: 0.9768999814987183
# epoch: 7, test_error_value: 0.06860809028148651, test accuracy: 0.9786999821662903
# epoch: 8, test_error_value: 0.06823629140853882, test accuracy: 0.9787999987602234
# epoch: 9, test_error_value: 0.06262961775064468, test accuracy: 0.9811000227928162
# epoch: 10, test_error_value: 0.05880260095000267, test accuracy: 0.9812999963760376
# epoch: 11, test_error_value: 0.06333067268133163, test accuracy: 0.98089998960495
# epoch: 12, test_error_value: 0.06248655542731285, test accuracy: 0.9804999828338623
# epoch: 13, test_error_value: 0.07081427425146103, test accuracy: 0.9782000184059143
# epoch: 14, test_error_value: 0.05850444361567497, test accuracy: 0.9825000166893005
# epoch: 15, test_error_value: 0.05456953123211861, test accuracy: 0.984499990940094
# epoch: 16, test_error_value: 0.057074908167123795, test accuracy: 0.9832000136375427
# epoch: 17, test_error_value: 0.05174803361296654, test accuracy: 0.9842000007629395
# epoch: 18, test_error_value: 0.05694793537259102, test accuracy: 0.9836999773979187
# epoch: 19, test_error_value: 0.054892607033252716, test accuracy: 0.9833999872207642
# epoch: 20, test_error_value: 0.05462123453617096, test accuracy: 0.9846000075340271
# epoch: 21, test_error_value: 0.06222066655755043, test accuracy: 0.9833999872207642
# epoch: 22, test_error_value: 0.04967796057462692, test accuracy: 0.9860000014305115
# epoch: 23, test_error_value: 0.049680549651384354, test accuracy: 0.9857000112533569
# epoch: 24, test_error_value: 0.04979979619383812, test accuracy: 0.9865000247955322
# epoch: 25, test_error_value: 0.05391790717840195, test accuracy: 0.9857000112533569
# epoch: 26, test_error_value: 0.052296657115221024, test accuracy: 0.9853000044822693
# epoch: 27, test_error_value: 0.052567701786756516, test accuracy: 0.9842000007629395
# epoch: 28, test_error_value: 0.048333197832107544, test accuracy: 0.9871000051498413
# epoch: 29, test_error_value: 0.05158664658665657, test accuracy: 0.9839000105857849
# epoch: 30, test_error_value: 0.04897666722536087, test accuracy: 0.9861000180244446
# epoch: 31, test_error_value: 0.05561293289065361, test accuracy: 0.9864000082015991
# epoch: 32, test_error_value: 0.05364986136555672, test accuracy: 0.9860000014305115
# epoch: 33, test_error_value: 0.07023048400878906, test accuracy: 0.9815000295639038
# epoch: 34, test_error_value: 0.05292268097400665, test accuracy: 0.9857000112533569
# epoch: 35, test_error_value: 0.05154026672244072, test accuracy: 0.9860000014305115
# epoch: 36, test_error_value: 0.056718602776527405, test accuracy: 0.9861999750137329
# epoch: 37, test_error_value: 0.05679021030664444, test accuracy: 0.9860000014305115
# epoch: 38, test_error_value: 0.05222640559077263, test accuracy: 0.9861000180244446
# epoch: 39, test_error_value: 0.052689630538225174, test accuracy: 0.9857000112533569
# epoch: 40, test_error_value: 0.06161218136548996, test accuracy: 0.9836999773979187
# epoch: 41, test_error_value: 0.06053309887647629, test accuracy: 0.9854000210762024
# epoch: 42, test_error_value: 0.06551375985145569, test accuracy: 0.9843999743461609
# epoch: 43, test_error_value: 0.059984367340803146, test accuracy: 0.9851999878883362
# epoch: 44, test_error_value: 0.06073158606886864, test accuracy: 0.9855999946594238
# epoch: 45, test_error_value: 0.06425511837005615, test accuracy: 0.9846000075340271
# epoch: 46, test_error_value: 0.06283649802207947, test accuracy: 0.9848999977111816
# epoch: 47, test_error_value: 0.0607089102268219, test accuracy: 0.9840999841690063
# epoch: 48, test_error_value: 0.0679478645324707, test accuracy: 0.9843000173568726
# epoch: 49, test_error_value: 0.06331143528223038, test accuracy: 0.9851999878883362
# epoch: 50, test_error_value: 0.05764572694897652, test accuracy: 0.98580002784729
# epoch: 51, test_error_value: 0.05416179820895195, test accuracy: 0.9869999885559082
# epoch: 52, test_error_value: 0.06047173961997032, test accuracy: 0.98580002784729
# epoch: 53, test_error_value: 0.05474289506673813, test accuracy: 0.9878000020980835
# epoch: 54, test_error_value: 0.05958913639187813, test accuracy: 0.9879000186920166
# epoch: 55, test_error_value: 0.05768516659736633, test accuracy: 0.9871000051498413
# epoch: 56, test_error_value: 0.0621483288705349, test accuracy: 0.9854000210762024
# epoch: 57, test_error_value: 0.05897470563650131, test accuracy: 0.9865000247955322
# epoch: 58, test_error_value: 0.05891599878668785, test accuracy: 0.9861999750137329
# epoch: 59, test_error_value: 0.06499902158975601, test accuracy: 0.9865000247955322
# epoch: 60, test_error_value: 0.06361593306064606, test accuracy: 0.9866999983787537
# epoch: 61, test_error_value: 0.06909395754337311, test accuracy: 0.9858999848365784
# epoch: 62, test_error_value: 0.07680828869342804, test accuracy: 0.9839000105857849
# epoch: 63, test_error_value: 0.05990279093384743, test accuracy: 0.9861999750137329
# epoch: 64, test_error_value: 0.05884340777993202, test accuracy: 0.9868000149726868
# epoch: 65, test_error_value: 0.05976743623614311, test accuracy: 0.9868000149726868
# epoch: 66, test_error_value: 0.06343838572502136, test accuracy: 0.9865000247955322
# epoch: 67, test_error_value: 0.06010149046778679, test accuracy: 0.9868999719619751
# epoch: 68, test_error_value: 0.06162416934967041, test accuracy: 0.9865000247955322
# epoch: 69, test_error_value: 0.06388813257217407, test accuracy: 0.9861999750137329
# epoch: 70, test_error_value: 0.06546817719936371, test accuracy: 0.98580002784729
# epoch: 71, test_error_value: 0.057825829833745956, test accuracy: 0.9878000020980835
# epoch: 72, test_error_value: 0.07837668806314468, test accuracy: 0.9851999878883362
# epoch: 73, test_error_value: 0.062402643263339996, test accuracy: 0.987500011920929
# epoch: 74, test_error_value: 0.057765714824199677, test accuracy: 0.9883999824523926
# epoch: 75, test_error_value: 0.058979835361242294, test accuracy: 0.9876999855041504
# epoch: 76, test_error_value: 0.06254763156175613, test accuracy: 0.9886999726295471
# epoch: 77, test_error_value: 0.06365068256855011, test accuracy: 0.9882000088691711
# epoch: 78, test_error_value: 0.06651491671800613, test accuracy: 0.984499990940094
# epoch: 79, test_error_value: 0.05365651845932007, test accuracy: 0.9878000020980835
# epoch: 80, test_error_value: 0.05959846079349518, test accuracy: 0.9864000082015991
# epoch: 81, test_error_value: 0.05962711200118065, test accuracy: 0.9865999817848206
# epoch: 82, test_error_value: 0.05907315015792847, test accuracy: 0.9871000051498413
# epoch: 83, test_error_value: 0.061028674244880676, test accuracy: 0.9871000051498413
# epoch: 84, test_error_value: 0.06210096552968025, test accuracy: 0.9873999953269958
# epoch: 85, test_error_value: 0.06393427401781082, test accuracy: 0.9868999719619751
# epoch: 86, test_error_value: 0.09069251269102097, test accuracy: 0.9804999828338623
# epoch: 87, test_error_value: 0.06889728456735611, test accuracy: 0.9865999817848206
# epoch: 88, test_error_value: 0.055683985352516174, test accuracy: 0.9876000285148621
# epoch: 89, test_error_value: 0.06614328920841217, test accuracy: 0.9873999953269958
# epoch: 90, test_error_value: 0.06324966996908188, test accuracy: 0.9882000088691711
# epoch: 91, test_error_value: 0.06484346836805344, test accuracy: 0.9872999787330627
# epoch: 92, test_error_value: 0.0656285360455513, test accuracy: 0.9869999885559082
# epoch: 93, test_error_value: 0.06562388688325882, test accuracy: 0.9864000082015991
# epoch: 94, test_error_value: 0.06264013797044754, test accuracy: 0.9868000149726868
# epoch: 95, test_error_value: 0.0631815567612648, test accuracy: 0.9876999855041504
# epoch: 96, test_error_value: 0.06523093581199646, test accuracy: 0.9873999953269958
# epoch: 97, test_error_value: 0.06906001269817352, test accuracy: 0.986299991607666
# epoch: 98, test_error_value: 0.06211813539266586, test accuracy: 0.9872999787330627
# epoch: 99, test_error_value: 0.062115833163261414, test accuracy: 0.9860000014305115
# train complete!
# Error Index: 8, Prediction: 6, Ground Truth: 5
# Error Index: 115, Prediction: 9, Ground Truth: 4
# Error Index: 149, Prediction: 9, Ground Truth: 2
# Error Index: 193, Prediction: 8, Ground Truth: 9
# Error Index: 247, Prediction: 6, Ground Truth: 4
# Error Index: 321, Prediction: 7, Ground Truth: 2
# Error Index: 324, Prediction: 1, Ground Truth: 0
# Error Index: 326, Prediction: 6, Ground Truth: 2
# Error Index: 358, Prediction: 3, Ground Truth: 7
# Error Index: 445, Prediction: 0, Ground Truth: 6
