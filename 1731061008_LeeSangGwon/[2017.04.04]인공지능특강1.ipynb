# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import math
import tensorflow as tf
print(tf.__version__)

# %matplotlib inline
# Out:
# 1.0.1

# %%
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print(type(mnist.train.images), mnist.train.images.shape)
print(type(mnist.train.labels), mnist.train.labels.shape)
# Out:
# <class 'numpy.ndarray'> (55000, 784)
# <class 'numpy.ndarray'> (55000, 10)

# %%
fig = plt.figure(figsize=(20, 5))
for i in range(5):
    img = np.array(mnist.train.images[i])
    img.shape = (28, 28)
    plt.subplot(150 + (i+1))
    plt.imshow(img, cmap='gray')

# %%
print(type(mnist.validation.images), mnist.validation.images.shape)
print(type(mnist.validation.labels), mnist.validation.labels.shape)
# Out:
# <class 'numpy.ndarray'> (5000, 784)
# <class 'numpy.ndarray'> (5000, 10)

# %%
print(type(mnist.test.images), mnist.test.images.shape)
print(type(mnist.test.labels), mnist.test.labels.shape)
# Out:
# <class 'numpy.ndarray'> (10000, 784)
# <class 'numpy.ndarray'> (10000, 10)

# %%
W_ = np.array([[1, 2, 3], [4, 5, 6]])  #shape of W: (2, 3)
x_ = np.array([[1, 2]])                #shape of x: (1, 2)
xW_ = np.dot(x_, W_)                     #shape of xW: (1, 3)
print(W_.shape, x_.shape, xW_.shape)
print(xW_)

print()

b_ = np.array([10, 20, 30])            #shape of b: (3,)
u_ = xW_ + b_                            #shape of u: (1, 3) 
print(b_.shape, u_.shape)
print(u_)
# Out:
# (2, 3) (1, 2) (1, 3)
# [[ 9 12 15]]
#
# (3,) (1, 3)
# [[19 32 45]]

# %%
batch_images, batch_labels = mnist.train.next_batch(100)
print(batch_images.shape)
#print batch_images
print

print(batch_labels.shape)
#print batch_labels
# Out:
# (100, 784)
# (100, 10)

# %%
W_ = np.array([[1, 2, 3], [4, 5, 6]])                    #shape of W: (2, 3)
x_ = np.array([[1, 2], [1, 2], [1, 2], [1, 2], [1, 2]])  #shape of x: (5, 2)
xW_ = np.dot(x_, W_)                                       #shape of xW: (5, 3)
print(W_.shape, x_.shape, xW_.shape)
print(xW_)

print()

b_ = np.array([10, 20, 30])            #shape of b: (3,)
u_ = xW_ + b_                            #shape of u: (1, 3) 
print(b_.shape, u_.shape)
print(u_)
# Out:
# (2, 3) (5, 2) (5, 3)
# [[ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]
#  [ 9 12 15]]
#
# (3,) (5, 3)
# [[19 32 45]
#  [19 32 45]
#  [19 32 45]
#  [19 32 45]
#  [19 32 45]]

# %%
x = tf.placeholder(tf.float32, [None, 784])
print("x -", x.get_shape())
# Out:
# x - (?, 784)

# %%
y_target = tf.placeholder(tf.float32, [None, 10])

# %%
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))
print("W -", W.get_shape())
print("b -", b.get_shape())
# Out:
# W - (784, 10)
# b - (10,)

# %%
u = tf.matmul(x, W) + b
print("u -", u.get_shape())
# Out:
# u - (?, 10)

# %%
learning_rate = 0.05
error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=u, labels=y_target))
optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(error)

# %%
prediction_and_ground_truth = tf.equal(tf.argmax(u, 1), tf.argmax(y_target, 1))
accuracy = tf.reduce_mean(tf.cast(prediction_and_ground_truth, tf.float32))

def draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list):
    # Draw Error Values and Accuracy
    fig = plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(epoch_list[1:], train_error_list[1:], 'r', label='Train')
    plt.plot(epoch_list[1:], validation_error_list[1:], 'g', label='Validation')
    plt.ylabel('Total Error')
    plt.xlabel('Epochs')
    plt.grid(True)
    plt.legend(loc='upper right')

    plt.subplot(122)
    plt.plot(epoch_list[1:], test_accuracy_list[1:], 'b', label='Test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.yticks(np.arange(0.0, 1.0, 0.05))
    plt.grid(True)
    plt.legend(loc='lower right')
    plt.show()
    
def draw_false_prediction(diff_index_list):
    fig = plt.figure(figsize=(20, 5))
    for i in range(5):
        j = diff_index_list[i]
        print("False Prediction Index: %s, Prediction: %s, Ground Truth: %s" % (j, prediction[j], ground_truth[j]))
        img = np.array(mnist.test.images[j])
        img.shape = (28, 28)
        plt.subplot(150 + (i+1))
        plt.imshow(img, cmap='gray')
    
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    
    batch_size = 100
    total_batch = int(math.ceil(mnist.train.num_examples/float(batch_size)))
    print("Total batch: %d" % total_batch)    

    training_epochs = 50
    epoch_list = []
    train_error_list = []
    validation_error_list = []
    test_accuracy_list = []
    for epoch in range(training_epochs):
        epoch_list.append(epoch)
        # Train Error Value
        train_error_value = sess.run(error, feed_dict={x: mnist.train.images, y_target: mnist.train.labels})
        train_error_list.append(train_error_value)
        
        validation_error_value = sess.run(error, feed_dict={x: mnist.validation.images, y_target: mnist.validation.labels})
        validation_error_list.append(validation_error_value)
        
        test_accuracy_value = sess.run(accuracy, feed_dict={x: mnist.test.images, y_target: mnist.test.labels})
        test_accuracy_list.append(test_accuracy_value) 
        print("Epoch: {0:2d}, Train Error: {1:0.5f}, Validation Error: {2:0.5f}, Test Accuracy: {3:0.5f}".format(epoch, train_error_value, validation_error_value, test_accuracy_value))
        
        for i in range(total_batch):
            batch_images, batch_labels = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={x: batch_images, y_target: batch_labels})
    

    # Draw Graph about Error Values & Accuracy Values
    draw_error_values_and_accuracy(epoch_list, train_error_list, validation_error_list, test_accuracy_list)
    
    # False Prediction Profile
    prediction = sess.run(tf.argmax(u, 1), feed_dict={x:mnist.test.images})
    ground_truth = sess.run(tf.argmax(y_target, 1), feed_dict={y_target:mnist.test.labels})

    print(prediction)
    print(ground_truth)

    diff_index_list = []
    for i in range(mnist.test.num_examples):
        if (prediction[i] != ground_truth[i]):
            diff_index_list.append(i)
            
    print("Number of False Prediction:", len(diff_index_list))
    draw_false_prediction(diff_index_list)
# Out:
# Total batch: 550
# Epoch:  0, Train Error: 2.30271, Validation Error: 2.30257, Test Accuracy: 0.09800
# Epoch:  1, Train Error: 0.45233, Validation Error: 0.43071, Test Accuracy: 0.89120
# Epoch:  2, Train Error: 0.38915, Validation Error: 0.36708, Test Accuracy: 0.90260
# Epoch:  3, Train Error: 0.36048, Validation Error: 0.33971, Test Accuracy: 0.90880
# Epoch:  4, Train Error: 0.34411, Validation Error: 0.32462, Test Accuracy: 0.91110
# Epoch:  5, Train Error: 0.33267, Validation Error: 0.31362, Test Accuracy: 0.91280
# Epoch:  6, Train Error: 0.32492, Validation Error: 0.30672, Test Accuracy: 0.91400
# Epoch:  7, Train Error: 0.31768, Validation Error: 0.30063, Test Accuracy: 0.91590
# Epoch:  8, Train Error: 0.31310, Validation Error: 0.29667, Test Accuracy: 0.91710
# Epoch:  9, Train Error: 0.30799, Validation Error: 0.29304, Test Accuracy: 0.91840
# Epoch: 10, Train Error: 0.30386, Validation Error: 0.28922, Test Accuracy: 0.91780
# Epoch: 11, Train Error: 0.30154, Validation Error: 0.28791, Test Accuracy: 0.91950
# Epoch: 12, Train Error: 0.29817, Validation Error: 0.28515, Test Accuracy: 0.91810
# Epoch: 13, Train Error: 0.29569, Validation Error: 0.28256, Test Accuracy: 0.91860
# Epoch: 14, Train Error: 0.29303, Validation Error: 0.28076, Test Accuracy: 0.92010
# Epoch: 15, Train Error: 0.29196, Validation Error: 0.28020, Test Accuracy: 0.91990
# Epoch: 16, Train Error: 0.28949, Validation Error: 0.27851, Test Accuracy: 0.92000
# Epoch: 17, Train Error: 0.28722, Validation Error: 0.27628, Test Accuracy: 0.92100
# Epoch: 18, Train Error: 0.28610, Validation Error: 0.27586, Test Accuracy: 0.92100
# Epoch: 19, Train Error: 0.28499, Validation Error: 0.27470, Test Accuracy: 0.92110
# Epoch: 20, Train Error: 0.28332, Validation Error: 0.27360, Test Accuracy: 0.92160
# Epoch: 21, Train Error: 0.28211, Validation Error: 0.27306, Test Accuracy: 0.92180
# Epoch: 22, Train Error: 0.28082, Validation Error: 0.27173, Test Accuracy: 0.92240
# Epoch: 23, Train Error: 0.27916, Validation Error: 0.27082, Test Accuracy: 0.92210
# Epoch: 24, Train Error: 0.27886, Validation Error: 0.27083, Test Accuracy: 0.92160
# Epoch: 25, Train Error: 0.27744, Validation Error: 0.26998, Test Accuracy: 0.92180
# Epoch: 26, Train Error: 0.27658, Validation Error: 0.26950, Test Accuracy: 0.92120
# Epoch: 27, Train Error: 0.27651, Validation Error: 0.26953, Test Accuracy: 0.92430
# Epoch: 28, Train Error: 0.27497, Validation Error: 0.26801, Test Accuracy: 0.92190
# Epoch: 29, Train Error: 0.27438, Validation Error: 0.26886, Test Accuracy: 0.92370
# Epoch: 30, Train Error: 0.27300, Validation Error: 0.26720, Test Accuracy: 0.92240
# Epoch: 31, Train Error: 0.27264, Validation Error: 0.26710, Test Accuracy: 0.92380
# Epoch: 32, Train Error: 0.27194, Validation Error: 0.26696, Test Accuracy: 0.92220
# Epoch: 33, Train Error: 0.27111, Validation Error: 0.26612, Test Accuracy: 0.92350
# Epoch: 34, Train Error: 0.27032, Validation Error: 0.26539, Test Accuracy: 0.92290
# Epoch: 35, Train Error: 0.27035, Validation Error: 0.26634, Test Accuracy: 0.92260
# Epoch: 36, Train Error: 0.26925, Validation Error: 0.26576, Test Accuracy: 0.92390
# Epoch: 37, Train Error: 0.26880, Validation Error: 0.26559, Test Accuracy: 0.92350
# Epoch: 38, Train Error: 0.26820, Validation Error: 0.26520, Test Accuracy: 0.92300
# Epoch: 39, Train Error: 0.26769, Validation Error: 0.26453, Test Accuracy: 0.92330
# Epoch: 40, Train Error: 0.26729, Validation Error: 0.26433, Test Accuracy: 0.92330
# Epoch: 41, Train Error: 0.26664, Validation Error: 0.26411, Test Accuracy: 0.92280
# Epoch: 42, Train Error: 0.26599, Validation Error: 0.26354, Test Accuracy: 0.92320
# Epoch: 43, Train Error: 0.26539, Validation Error: 0.26376, Test Accuracy: 0.92370
# Epoch: 44, Train Error: 0.26495, Validation Error: 0.26327, Test Accuracy: 0.92430
# Epoch: 45, Train Error: 0.26473, Validation Error: 0.26259, Test Accuracy: 0.92350
# Epoch: 46, Train Error: 0.26434, Validation Error: 0.26255, Test Accuracy: 0.92280
# Epoch: 47, Train Error: 0.26426, Validation Error: 0.26320, Test Accuracy: 0.92370
# Epoch: 48, Train Error: 0.26450, Validation Error: 0.26272, Test Accuracy: 0.92450
# Epoch: 49, Train Error: 0.26282, Validation Error: 0.26212, Test Accuracy: 0.92430
# [7 2 1 ..., 4 5 6]
# [7 2 1 ..., 4 5 6]
# Number of False Prediction: 765
# False Prediction Index: 8, Prediction: 6, Ground Truth: 5
# False Prediction Index: 33, Prediction: 6, Ground Truth: 4
# False Prediction Index: 63, Prediction: 2, Ground Truth: 3
# False Prediction Index: 66, Prediction: 7, Ground Truth: 6
# False Prediction Index: 92, Prediction: 4, Ground Truth: 9
