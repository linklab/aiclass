# %%
# pip install numba --upgrade
# pip install pygraphviz
import sys
sys.path.insert(0, "/home/ubuntu/git/aiclass/1732095003_hyunkyolim/")

import tensorflux.graph as tfg
import tensorflux.Multi_Layer_Network as tfn
import tensorflux.enums as tfe
import datasource.mnist as mnist
import tensorflux.functions as tff

# %%
"""
    (affine0 - batch_normal0 - relu0 - dropout0) - 
    (affine1 - batch_normal1 - relu1 - dropout1) - affine2 - softmax (output)
"""
input_size = 784
hidden_layer0_size = 128
hidden_layer1_size = 128
dropout_ratio0 = 0.5
dropout_ratio1 = 0.5
output_size = 10

x = tfg.Placeholder(name="x")
target = tfg.Placeholder(name="target")

n = tfn.Multi_Layer_Network(
    input_size=input_size,
    hidden_size_list=[hidden_layer0_size, hidden_layer1_size],
    output_size=output_size,
    input_node=x,
    target_node=target,
    use_batch_normalization=True,
    use_dropout=True,
    dropout_ratio_list=[dropout_ratio0, dropout_ratio1],
    initializer=tfe.Initializer.Normal.value,
    init_sd=0.01,
    # initializer=tfe.Initializer.Xavier.value,
    activator=tfe.Activator.ReLU.value,
    optimizer=tfe.Optimizer.Adam.value,
    learning_rate=0.001
)
# Out:
# Multi Layer Network Model - ID: D6J86UP2

# %%
n.draw_and_show(figsize=(20, 10))

# %%
data = mnist.MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)
#data = mnist.Fashion_MNIST_Data(validation_size=5000, n_splits=12, is_onehot_target=True)

# %%
forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
#print(forward_final_output.shape)
print("Initial Accuracy", tff.accuracy(forward_final_output, data.test_target))

batch_size = 1000
#%timeit -n1 -r1 n.learning(
n.learning(
    max_epoch=10, 
    data=data, 
    batch_size=batch_size, 
    print_period=1, 
    is_numba=False, 
    verbose=False
)
data.reset_kfold()

forward_final_output = n.feed_forward(input_data=data.test_input, is_numba=False)
print("Post-learning Accuracy", tff.accuracy(forward_final_output, data.test_target))
# Out:
# Initial Accuracy 0.104
# -- Learning Started --
# Epoch   0 Completed - Train Error:2.30258 - Validation Error:2.30257 - Test Accuracy:0.11830 <== Minimal Val. Error
# Fold:  0
# Epoch   1 Completed - Train Error:2.30094 - Validation Error:2.30117 - Test Accuracy:0.11350 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:2.27642 - Validation Error:2.28116 - Test Accuracy:0.11350 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:1.85442 - Validation Error:1.86296 - Test Accuracy:0.53270 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:1.04220 - Validation Error:1.03495 - Test Accuracy:0.81450 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.50049 - Validation Error:0.51562 - Test Accuracy:0.92850 <== Minimal Val. Error
# Epoch   6 Completed - Train Error:0.26904 - Validation Error:0.30676 - Test Accuracy:0.94580 <== Minimal Val. Error
# Epoch   7 Completed - Train Error:0.19619 - Validation Error:0.22374 - Test Accuracy:0.95360 <== Minimal Val. Error
# Epoch   8 Completed - Train Error:0.16564 - Validation Error:0.18766 - Test Accuracy:0.95760 <== Minimal Val. Error
# Epoch   9 Completed - Train Error:0.13249 - Validation Error:0.16841 - Test Accuracy:0.96220 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.14235 - Validation Error:0.15052 - Test Accuracy:0.96390 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 10 (Fold:  0 & Epoch: 10) - Train Error:0.14235 - Validation Error:0.15052 - Test Accuracy:0.96390
#
# Fold:  1
# Epoch   1 Completed - Train Error:0.10561 - Validation Error:0.12671 - Test Accuracy:0.96690 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.09238 - Validation Error:0.12026 - Test Accuracy:0.96860 <== Minimal Val. Error
# Epoch   3 Completed - Train Error:0.09918 - Validation Error:0.11863 - Test Accuracy:0.96590 <== Minimal Val. Error
# Epoch   4 Completed - Train Error:0.07750 - Validation Error:0.11221 - Test Accuracy:0.96950 <== Minimal Val. Error
# Epoch   5 Completed - Train Error:0.08034 - Validation Error:0.10830 - Test Accuracy:0.96940 <== Minimal Val. Error
# Epoch   6 Completed - Train Error:0.07655 - Validation Error:0.10551 - Test Accuracy:0.96910 <== Minimal Val. Error
# Epoch   7 Completed - Train Error:0.06793 - Validation Error:0.10332 - Test Accuracy:0.97040 <== Minimal Val. Error
# Epoch   8 Completed - Train Error:0.06795 - Validation Error:0.10303 - Test Accuracy:0.97110 <== Minimal Val. Error
# Epoch   9 Completed - Train Error:0.05650 - Validation Error:0.10277 - Test Accuracy:0.97090 <== Minimal Val. Error
# Epoch  10 Completed - Train Error:0.06575 - Validation Error:0.09810 - Test Accuracy:0.97220 <== Minimal Val. Error
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 20 (Fold:  1 & Epoch: 10) - Train Error:0.06575 - Validation Error:0.09810 - Test Accuracy:0.97220
#
# Fold:  2
# Epoch   1 Completed - Train Error:0.06634 - Validation Error:0.05683 - Test Accuracy:0.97180 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.05430 - Validation Error:0.06126 - Test Accuracy:0.97190
# Epoch   3 Completed - Train Error:0.04999 - Validation Error:0.06132 - Test Accuracy:0.97220
# Epoch   4 Completed - Train Error:0.05668 - Validation Error:0.05914 - Test Accuracy:0.97130
# Epoch   5 Completed - Train Error:0.07066 - Validation Error:0.06123 - Test Accuracy:0.97300
# Epoch   6 Completed - Train Error:0.04198 - Validation Error:0.05780 - Test Accuracy:0.97380
# Epoch   7 Completed - Train Error:0.05425 - Validation Error:0.06081 - Test Accuracy:0.97410
# Epoch   8 Completed - Train Error:0.03587 - Validation Error:0.06394 - Test Accuracy:0.97300
# Epoch   9 Completed - Train Error:0.04136 - Validation Error:0.06358 - Test Accuracy:0.97310
# Epoch  10 Completed - Train Error:0.04124 - Validation Error:0.06297 - Test Accuracy:0.97440
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 21 (Fold:  2 & Epoch:  1) - Train Error:0.06634 - Validation Error:0.05683 - Test Accuracy:0.97180
#
# Fold:  3
# Epoch   1 Completed - Train Error:0.03460 - Validation Error:0.04414 - Test Accuracy:0.97410 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.03529 - Validation Error:0.04573 - Test Accuracy:0.97490
# Epoch   3 Completed - Train Error:0.04055 - Validation Error:0.04547 - Test Accuracy:0.97560
# Epoch   4 Completed - Train Error:0.03262 - Validation Error:0.04792 - Test Accuracy:0.97420
# Epoch   5 Completed - Train Error:0.04307 - Validation Error:0.05360 - Test Accuracy:0.97410
# Epoch   6 Completed - Train Error:0.03157 - Validation Error:0.05168 - Test Accuracy:0.97490
# Epoch   7 Completed - Train Error:0.02286 - Validation Error:0.05307 - Test Accuracy:0.97420
# Epoch   8 Completed - Train Error:0.02218 - Validation Error:0.05178 - Test Accuracy:0.97430
# Epoch   9 Completed - Train Error:0.02707 - Validation Error:0.05412 - Test Accuracy:0.97430
# Epoch  10 Completed - Train Error:0.03232 - Validation Error:0.05222 - Test Accuracy:0.97520
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 31 (Fold:  3 & Epoch:  1) - Train Error:0.03460 - Validation Error:0.04414 - Test Accuracy:0.97410
#
# Fold:  4
# Epoch   1 Completed - Train Error:0.04027 - Validation Error:0.04162 - Test Accuracy:0.97480 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.03723 - Validation Error:0.04643 - Test Accuracy:0.97560
# Epoch   3 Completed - Train Error:0.03091 - Validation Error:0.04806 - Test Accuracy:0.97510
# Epoch   4 Completed - Train Error:0.03193 - Validation Error:0.05026 - Test Accuracy:0.97520
# Epoch   5 Completed - Train Error:0.03403 - Validation Error:0.05020 - Test Accuracy:0.97470
# Epoch   6 Completed - Train Error:0.03672 - Validation Error:0.05443 - Test Accuracy:0.97490
# Epoch   7 Completed - Train Error:0.03237 - Validation Error:0.05670 - Test Accuracy:0.97530
# Epoch   8 Completed - Train Error:0.02224 - Validation Error:0.05576 - Test Accuracy:0.97500
# Epoch   9 Completed - Train Error:0.02864 - Validation Error:0.05535 - Test Accuracy:0.97600
# Epoch  10 Completed - Train Error:0.03598 - Validation Error:0.05969 - Test Accuracy:0.97600
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 41 (Fold:  4 & Epoch:  1) - Train Error:0.04027 - Validation Error:0.04162 - Test Accuracy:0.97480
#
# Fold:  5
# Epoch   1 Completed - Train Error:0.03607 - Validation Error:0.02586 - Test Accuracy:0.97520 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.02093 - Validation Error:0.02678 - Test Accuracy:0.97470
# Epoch   3 Completed - Train Error:0.02281 - Validation Error:0.02911 - Test Accuracy:0.97500
# Epoch   4 Completed - Train Error:0.03040 - Validation Error:0.03084 - Test Accuracy:0.97500
# Epoch   5 Completed - Train Error:0.02676 - Validation Error:0.03121 - Test Accuracy:0.97530
# Epoch   6 Completed - Train Error:0.02031 - Validation Error:0.03532 - Test Accuracy:0.97520
# Epoch   7 Completed - Train Error:0.02432 - Validation Error:0.03440 - Test Accuracy:0.97460
# Epoch   8 Completed - Train Error:0.01530 - Validation Error:0.03509 - Test Accuracy:0.97640
# Epoch   9 Completed - Train Error:0.02059 - Validation Error:0.03607 - Test Accuracy:0.97560
# Epoch  10 Completed - Train Error:0.03141 - Validation Error:0.03666 - Test Accuracy:0.97520
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.03607 - Validation Error:0.02586 - Test Accuracy:0.97520
#
# Fold:  6
# Epoch   1 Completed - Train Error:0.01655 - Validation Error:0.02633 - Test Accuracy:0.97530
# Epoch   2 Completed - Train Error:0.03941 - Validation Error:0.03112 - Test Accuracy:0.97570
# Epoch   3 Completed - Train Error:0.02534 - Validation Error:0.03434 - Test Accuracy:0.97460
# Epoch   4 Completed - Train Error:0.01090 - Validation Error:0.03609 - Test Accuracy:0.97550
# Epoch   5 Completed - Train Error:0.02399 - Validation Error:0.03807 - Test Accuracy:0.97640
# Epoch   6 Completed - Train Error:0.02165 - Validation Error:0.03921 - Test Accuracy:0.97610
# Epoch   7 Completed - Train Error:0.02312 - Validation Error:0.04080 - Test Accuracy:0.97510
# Epoch   8 Completed - Train Error:0.01662 - Validation Error:0.04137 - Test Accuracy:0.97610
# Epoch   9 Completed - Train Error:0.01221 - Validation Error:0.04068 - Test Accuracy:0.97690
# Epoch  10 Completed - Train Error:0.01127 - Validation Error:0.04396 - Test Accuracy:0.97550
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 51 (Fold:  5 & Epoch:  1) - Train Error:0.03607 - Validation Error:0.02586 - Test Accuracy:0.97520
#
# Fold:  7
# Epoch   1 Completed - Train Error:0.01747 - Validation Error:0.01999 - Test Accuracy:0.97570 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.02008 - Validation Error:0.02459 - Test Accuracy:0.97690
# Epoch   3 Completed - Train Error:0.02262 - Validation Error:0.02739 - Test Accuracy:0.97570
# Epoch   4 Completed - Train Error:0.01959 - Validation Error:0.02903 - Test Accuracy:0.97720
# Epoch   5 Completed - Train Error:0.01721 - Validation Error:0.03193 - Test Accuracy:0.97610
# Epoch   6 Completed - Train Error:0.00936 - Validation Error:0.03053 - Test Accuracy:0.97620
# Epoch   7 Completed - Train Error:0.01582 - Validation Error:0.03330 - Test Accuracy:0.97480
# Epoch   8 Completed - Train Error:0.02105 - Validation Error:0.03237 - Test Accuracy:0.97600
# Epoch   9 Completed - Train Error:0.01512 - Validation Error:0.03634 - Test Accuracy:0.97610
# Epoch  10 Completed - Train Error:0.01903 - Validation Error:0.03546 - Test Accuracy:0.97700
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 71 (Fold:  7 & Epoch:  1) - Train Error:0.01747 - Validation Error:0.01999 - Test Accuracy:0.97570
#
# Fold:  8
# Epoch   1 Completed - Train Error:0.02452 - Validation Error:0.01765 - Test Accuracy:0.97550 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.01057 - Validation Error:0.01934 - Test Accuracy:0.97530
# Epoch   3 Completed - Train Error:0.01621 - Validation Error:0.02465 - Test Accuracy:0.97660
# Epoch   4 Completed - Train Error:0.02323 - Validation Error:0.02438 - Test Accuracy:0.97640
# Epoch   5 Completed - Train Error:0.02179 - Validation Error:0.02244 - Test Accuracy:0.97590
# Epoch   6 Completed - Train Error:0.01315 - Validation Error:0.02625 - Test Accuracy:0.97630
# Epoch   7 Completed - Train Error:0.01937 - Validation Error:0.02750 - Test Accuracy:0.97700
# Epoch   8 Completed - Train Error:0.01392 - Validation Error:0.02816 - Test Accuracy:0.97740
# Epoch   9 Completed - Train Error:0.01785 - Validation Error:0.03130 - Test Accuracy:0.97620
# Epoch  10 Completed - Train Error:0.01589 - Validation Error:0.02915 - Test Accuracy:0.97560
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 81 (Fold:  8 & Epoch:  1) - Train Error:0.02452 - Validation Error:0.01765 - Test Accuracy:0.97550
#
# Fold:  9
# Epoch   1 Completed - Train Error:0.01714 - Validation Error:0.01414 - Test Accuracy:0.97630 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.01231 - Validation Error:0.01638 - Test Accuracy:0.97610
# Epoch   3 Completed - Train Error:0.01729 - Validation Error:0.01584 - Test Accuracy:0.97610
# Epoch   4 Completed - Train Error:0.01477 - Validation Error:0.01796 - Test Accuracy:0.97580
# Epoch   5 Completed - Train Error:0.00961 - Validation Error:0.02066 - Test Accuracy:0.97520
# Epoch   6 Completed - Train Error:0.02096 - Validation Error:0.02096 - Test Accuracy:0.97550
# Epoch   7 Completed - Train Error:0.01880 - Validation Error:0.02287 - Test Accuracy:0.97690
# Epoch   8 Completed - Train Error:0.01394 - Validation Error:0.02412 - Test Accuracy:0.97670
# Epoch   9 Completed - Train Error:0.01229 - Validation Error:0.02439 - Test Accuracy:0.97590
# Epoch  10 Completed - Train Error:0.01275 - Validation Error:0.02424 - Test Accuracy:0.97770
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch: 91 (Fold:  9 & Epoch:  1) - Train Error:0.01714 - Validation Error:0.01414 - Test Accuracy:0.97630
#
# Fold:  10
# Epoch   1 Completed - Train Error:0.00825 - Validation Error:0.01355 - Test Accuracy:0.97600 <== Minimal Val. Error
# Epoch   2 Completed - Train Error:0.00828 - Validation Error:0.01516 - Test Accuracy:0.97700
# Epoch   3 Completed - Train Error:0.00964 - Validation Error:0.01686 - Test Accuracy:0.97700
# Epoch   4 Completed - Train Error:0.01003 - Validation Error:0.01773 - Test Accuracy:0.97660
# Epoch   5 Completed - Train Error:0.01388 - Validation Error:0.01859 - Test Accuracy:0.97590
# Epoch   6 Completed - Train Error:0.00928 - Validation Error:0.01954 - Test Accuracy:0.97730
# Epoch   7 Completed - Train Error:0.01652 - Validation Error:0.02019 - Test Accuracy:0.97710
# Epoch   8 Completed - Train Error:0.00918 - Validation Error:0.02145 - Test Accuracy:0.97660
# Epoch   9 Completed - Train Error:0.01170 - Validation Error:0.02112 - Test Accuracy:0.97600
# Epoch  10 Completed - Train Error:0.01565 - Validation Error:0.02355 - Test Accuracy:0.97600
#
# [Best Epoch (based on Validation Error) and Its Performance]
# Global Epoch:101 (Fold: 10 & Epoch:  1) - Train Error:0.00825 - Validation Error:0.01355 - Test Accuracy:0.97600
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-5-5a881c4e8ce9> in <module>()
#      11     print_period=1,
#      12     is_numba=False,
# ---> 13     verbose=False
#      14 )
#      15 data.reset_kfold()
#
# /home/ubuntu/git/aiclass/1732095003_hyunkyolim/tensorflux/Multi_Layer_Network.py in learning(self, max_epoch, data, batch_size, print_period, is_numba, verbose)
#     266
#     267         for fold_idx in range(data.n_splits):
# --> 268             data.set_next_train_and_validation_data()
#     269             num_batch = math.ceil(data.num_train_data / batch_size)
#     270
#
# /home/ubuntu/git/aiclass/1732095003_hyunkyolim/datasource/data.py in set_next_train_and_validation_data(self)
#      11     def set_next_train_and_validation_data(self):
#      12         if self.n_splits > 1:
# ---> 13             train_indices, validation_indices = next(self.splitted_indices)
#      14
#      15             self.validation_input = self.images[validation_indices]
#
# StopIteration:

# %%
print("Epoch:{:3d}, Min Train Error:{:7.5f}, Min Validation Error:{:7.5f}, Test Accuracy:{:7.5f}".format(
    n.min_validation_error_epoch,
    n.min_train_error,
    n.min_validation_error,
    n.test_accuracy_at_min_validation_error_epoch
))

print("Mean of Min Va. Error For All Folds:{:7.5f}".format(n.mean_min_validation_error_for_all_folds))
# Out:
# Epoch:101, Min Train Error:0.00825, Min Validation Error:0.01355, Test Accuracy:0.97600
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0f3c3135bb84> in <module>()
#       6 ))
#       7
# ----> 8 print("Mean of Min Va. Error For All Folds:{:7.5f}".format(n.mean_min_validation_error_for_all_folds))
#
# AttributeError: 'Multi_Layer_Network' object has no attribute 'mean_min_validation_error_for_all_folds'

# %%
n.draw_error_values_and_accuracy(figsize=(20, 5))

# %%
n.draw_false_prediction(data.test_input, data.test_target, data.labels, num=5, figsize=(20, 5))
# Out:
# False Prediction Index: 213, Prediction: Seven, Ground Truth: Three
# False Prediction Index: 245, Prediction: One, Ground Truth: Three
# False Prediction Index: 247, Prediction: Two, Ground Truth: Four
# False Prediction Index: 259, Prediction: Zero, Ground Truth: Six
# False Prediction Index: 282, Prediction: Two, Ground Truth: Seven

# %%
n.draw_param_description(figsize=(20, 10))

# %%
n.draw_output_description(figsize=(20, 10))
